# %%
import numpy as np
import pandas as pd

df = pd.read_excel("/home/shravan/Desktop/Datasets/pharma/pfizer/pfizer.xlsx")

print(df.head())
print("\n****\n",df.tail())

print("_________________________________________________________\n\nOPEN \n\tAverage : ",np.mean(df.loc[:]['Open']),"\n\tMaximum : ", np.max(df['Open']),"\n\tMinimum : ", np.min(df['Open']),"\n\tStandard Deviation : ", np.std(df['Open']))
print("\n\nHIGH \n\tAverage : ",np.mean(df.loc[:]['High']),"\n\tMaximum : ", np.max(df['High']),"\n\tMinimum : ", np.min(df['High']),"\n\tStandard Deviation : ", np.std(df['High']))
print("\n\nLOW \n\tAverage : ",np.mean(df.loc[:]['Low']),"\n\tMaximum : ", np.max(df['Low']),"\n\tMinimum : ", np.min(df['Low']),"\n\tStandard Deviation : ", np.std(df['Low']))
print("\n\nCLOSE \n\tAverage : ",np.mean(df.loc[:]['Close']),"\n\tMaximum : ", np.max(df['Close']),"\n\tMinimum : ", np.min(df['Close']),"\n\tStandard Deviation : ", np.std(df['Close']))
print("\n\nVOLUME \n\tAverage : ",np.mean(df.loc[:]['Volume']),"\n\tMaximum : ", np.max(df['Volume']),"\n\tMinimum : ", np.min(df['Volume']),"\n\tStandard Deviation : ", np.std(df['Volume']))

def reverse_data(df):
    date = []
    day = []
    open = []
    high = []
    low = []
    close = []
    volume = []
    for i in range(len(df)-1, -1, -1):
        day.append((len(df)-1)-i)
        date.append(df.loc[i]['Date '])
        open.append(df.loc[i]['Open'])
        high.append(df.loc[i]['High'])
        low.append(df.loc[i]['Low'])
        close.append(df.loc[i]['Close'])
        volume.append(df.loc[i]['Volume'])
    stocks = pd.DataFrame()
    stocks['Day'] = day
    stocks['Date'] = date
    stocks['Open'] = open
    stocks['High'] = high
    stocks['Low'] = low
    stocks['Close'] = close
    stocks['Volume'] = volume
    return stocks

stocks = reverse_data(df)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (30,10)
fig,ax = plt.subplots()

ax.plot(stocks['Day'],stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Pfizer Limited")
plt.show()
# Out:
#          Date     Open     High      Low    Close  Volume
# 0  29-Mar-2019  3300.0  3348.00  3265.00  3326.00   33841
# 1  28-Mar-2019  3251.0  3321.00  3230.00  3290.25   22424
# 2  27-Mar-2019  3220.6  3287.95  3191.05  3267.10   26351
# 3  26-Mar-2019  3165.0  3287.95  3144.00  3230.00   31056
# 4  25-Mar-2019  3166.0  3200.05  3135.00  3180.65   15472
#
# ****
#              Date     Open   High     Low   Close  Volume
# 2717  07-Apr-2008  672.35  694.5  662.15  685.90    5877
# 2718  04-Apr-2008  673.00  684.5  669.00  672.35   14869
# 2719  03-Apr-2008  675.00  691.8  669.10  684.05   11378
# 2720  02-Apr-2008  695.10  720.0  691.00  700.35   16497
# 2721  01-Apr-2008  700.00  700.0  675.00  694.70   14215
# _________________________________________________________
#
# OPEN
# 	Average :  1502.7655951506233
# 	Maximum :  3735.0
# 	Minimum :  450.0
# 	Standard Deviation :  646.3160392814301
#
#
# HIGH
# 	Average :  1524.758082292438
# 	Maximum :  3847.7
# 	Minimum :  454.1
# 	Standard Deviation :  655.7471248643697
#
#
# LOW
# 	Average :  1479.7705547391574
# 	Maximum :  3597.55
# 	Minimum :  435.0
# 	Standard Deviation :  634.510703479229
#
#
# CLOSE
# 	Average :  1501.0212711241725
# 	Maximum :  3731.9
# 	Minimum :  443.95
# 	Standard Deviation :  645.5745746211528
#
#
# VOLUME
# 	Average :  17575.136664217487
# 	Maximum :  645040
# 	Minimum :  75
# 	Standard Deviation :  36688.790495527
#    Day         Date    Open   High     Low   Close  Volume
# 0    0  01-Apr-2008  700.00  700.0  675.00  694.70   14215
# 1    1  02-Apr-2008  695.10  720.0  691.00  700.35   16497
# 2    2  03-Apr-2008  675.00  691.8  669.10  684.05   11378
# 3    3  04-Apr-2008  673.00  684.5  669.00  672.35   14869
# 4    4  07-Apr-2008  672.35  694.5  662.15  685.90    5877
#
# ****
#         Day         Date    Open     High      Low    Close  Volume
# 2717  2717  25-Mar-2019  3166.0  3200.05  3135.00  3180.65   15472
# 2718  2718  26-Mar-2019  3165.0  3287.95  3144.00  3230.00   31056
# 2719  2719  27-Mar-2019  3220.6  3287.95  3191.05  3267.10   26351
# 2720  2720  28-Mar-2019  3251.0  3321.00  3230.00  3290.25   22424
# 2721  2721  29-Mar-2019  3300.0  3348.00  3265.00  3326.00   33841

# %%
from sklearn.preprocessing import MinMaxScaler

def get_normalised_data(data):
    scaler = MinMaxScaler()
    numerical = ['Open','High','Low','Close','Volume']
    data[numerical] = scaler.fit_transform(data[numerical])
    return data

stocks = get_normalised_data(stocks)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,10)
fig,ax = plt.subplots()

ax.plot(stocks['Day'],stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Pfizer Limited")
plt.show()
# Out:
#    Day         Date      Open      High       Low     Close    Volume
# 0    0  01-Apr-2008  0.076104  0.072460  0.075888  0.076263  0.021924
# 1    1  02-Apr-2008  0.074612  0.078353  0.080947  0.077982  0.025462
# 2    2  03-Apr-2008  0.068493  0.070044  0.074023  0.073024  0.017525
# 3    3  04-Apr-2008  0.067884  0.067893  0.073991  0.069466  0.022938
# 4    4  07-Apr-2008  0.067686  0.070839  0.071825  0.073587  0.008996
#
# ****
#         Day         Date      Open      High       Low     Close    Volume
# 2717  2717  25-Mar-2019  0.826788  0.809155  0.853741  0.832342  0.023873
# 2718  2718  26-Mar-2019  0.826484  0.835057  0.856587  0.847352  0.048035
# 2719  2719  27-Mar-2019  0.843409  0.835057  0.871464  0.858635  0.040740
# 2720  2720  28-Mar-2019  0.852664  0.844796  0.883780  0.865676  0.034651
# 2721  2721  29-Mar-2019  0.867580  0.852752  0.894848  0.876549  0.052353

# %%
import math
from IPython.display import display
import time
from keras.layers.core import Dense,Dropout,Activation
from keras.models import Sequential
from keras.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from keras.layers.recurrent import LSTM
from keras.layers.recurrent import GRU
from keras.layers.recurrent import SimpleRNN

#UNROLL_FUNCTION
def unroll(stocks,unroll_length):
    result = []
    for i in range(len(stocks)-unroll_length+1):
        result.append(stocks[i : (i+unroll_length)])
    return np.asarray(result)



#LSTM_MODEL
def build_lstm_model(input_dim, output_dim, return_sequences):
    model = Sequential()
    model.add(LSTM(input_shape = (None, input_dim), units = output_dim, return_sequences = return_sequences))
    model.add(LSTM(units = 128, return_sequences = False))
    model.add(Dense(units = 200))
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    return model





def plot_prediction(actual, prediction, title='PFIZER TRADING VS PREDICTIONS', y_label='Price INR', x_label='Trading Days'):
    
    fig = plt.figure()
    ax = fig.add_subplot(111)

    # Add labels
    plt.ylabel(y_label)
    plt.xlabel(x_label)

    # Plot actual and predicted close values
    plt.plot(actual, '#00FF00', label='Adjusted Close')
    plt.plot(prediction, '#0000FF', label='Predicted Close')

    # Set title
    ax.set_title(title)
    ax.legend(loc='upper left')
    plt.show()
    return fig


#RESULT_STAT_FUNCTION
def err_stat(y_test,preds):
    Error = preds - y_test
    print("Standard Deviation of Error : ", np.std(Error))
    stdErr = np.std(Error)
    DstdErr = stdErr * (np.max(df['Close']) - np.min(df['Close']))
    print("Denormalised Standard Deviation : ", DstdErr)
    print("Ratio of Standard Deviation of Error to Standard Deviation of Stock Price : ", DstdErr/np.std(df['Close']))




#####
#TRAIN_TEST_SPLIT
stocks = stocks.drop(['Date','Day'], axis =1)
stocks.head()

def train_test_split(stocks,unroll_length,prediction_size,prediction_time):
    x_test_start = prediction_size + prediction_time + unroll_length - 1
    
    #train data
    x_train = stocks[0 : (-x_test_start - prediction_time)].to_numpy()
    y_train = stocks[ (unroll_length - 1 + prediction_time) : -x_test_start]['Close'].to_numpy()
    
    #test_data
    x_test = stocks[-x_test_start : -prediction_time].to_numpy()
    y_test = stocks[-prediction_size:]['Close'].to_numpy()

    
    return x_train,x_test,y_train,y_test

prediction_size = 494
prediction_time = 5
unroll_length = 50

x_train,x_test,y_train,y_test = train_test_split(stocks,unroll_length,prediction_size,prediction_time)

x_train = unroll(x_train,unroll_length)
x_test = unroll(x_test,unroll_length)

print("x_train", x_train.shape)
print("y_train", y_train.shape)
print("x_test", x_test.shape)
print("y_test", y_test.shape)

#####
# Out:
# x_train (2120, 50, 5)
# y_train (2120,)
# x_test (494, 50, 5)
# y_test (494,)

# %%
lstm_model = build_lstm_model(x_train.shape[-1], unroll_length, return_sequences = True)
lstm_model.compile(loss = "mean_squared_error", optimizer = 'Adam')
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, None, 50)          11200
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               91648
# _________________________________________________________________
# dense_2 (Dense)              (None, 200)               25800
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 201
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 128,849
# Trainable params: 128,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
#TRAIN_LSTM_MODEL
lstm_model = build_lstm_model(x_train.shape[-1], unroll_length, return_sequences = True)
lstm_model.compile(loss = "mean_squared_error", optimizer = 'Adam')
lstm_model.fit(x_train, y_train, epochs = 50, validation_split = 0.05)

preds_lstm = lstm_model.predict(x_test)
plot_prediction(y_test, preds_lstm)
err_stat(y_test,preds_lstm)

trainScore = lstm_model.evaluate(x_train, y_train, verbose=0)
print('Train Score: %.8f MSE (%.8f RMSE)' % (trainScore, math.sqrt(trainScore)))

testScore = lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test Score: %.8f MSE (%.8f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Epoch 1/50
# 63/63 [==============================] - 5s 46ms/step - loss: 0.0129 - val_loss: 2.5081e-04
# Epoch 2/50
# 63/63 [==============================] - 2s 33ms/step - loss: 5.8403e-04 - val_loss: 3.0269e-04
# Epoch 3/50
# 63/63 [==============================] - 2s 33ms/step - loss: 5.3207e-04 - val_loss: 2.2887e-04
# Epoch 4/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.7389e-04 - val_loss: 3.7539e-04
# Epoch 5/50
# 63/63 [==============================] - 2s 33ms/step - loss: 5.4138e-04 - val_loss: 2.2239e-04
# Epoch 6/50
# 63/63 [==============================] - 2s 33ms/step - loss: 5.0607e-04 - val_loss: 8.4131e-04
# Epoch 7/50
# 63/63 [==============================] - 2s 35ms/step - loss: 7.2188e-04 - val_loss: 3.3826e-04
# Epoch 8/50
# 63/63 [==============================] - 2s 33ms/step - loss: 5.9793e-04 - val_loss: 3.4356e-04
# Epoch 9/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.3904e-04 - val_loss: 2.1545e-04
# Epoch 10/50
# 63/63 [==============================] - 2s 33ms/step - loss: 5.0802e-04 - val_loss: 6.2508e-04
# Epoch 11/50
# 63/63 [==============================] - 2s 35ms/step - loss: 5.4212e-04 - val_loss: 1.9168e-04
# Epoch 12/50
# 63/63 [==============================] - 2s 36ms/step - loss: 4.6123e-04 - val_loss: 1.9943e-04
# Epoch 13/50
# 63/63 [==============================] - 2s 34ms/step - loss: 4.7479e-04 - val_loss: 2.0237e-04
# Epoch 14/50
# 63/63 [==============================] - 2s 34ms/step - loss: 4.1320e-04 - val_loss: 5.0471e-04
# Epoch 15/50
# 63/63 [==============================] - 2s 34ms/step - loss: 4.2876e-04 - val_loss: 6.7108e-04
# Epoch 16/50
# 63/63 [==============================] - 2s 35ms/step - loss: 5.3684e-04 - val_loss: 2.2852e-04
# Epoch 17/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.1699e-04 - val_loss: 1.7471e-04
# Epoch 18/50
# 63/63 [==============================] - 2s 34ms/step - loss: 4.5507e-04 - val_loss: 1.8300e-04
# Epoch 19/50
# 63/63 [==============================] - 2s 34ms/step - loss: 3.9916e-04 - val_loss: 2.4384e-04
# Epoch 20/50
# 63/63 [==============================] - 2s 34ms/step - loss: 5.3602e-04 - val_loss: 3.0925e-04
# Epoch 21/50
# 63/63 [==============================] - 2s 32ms/step - loss: 5.3094e-04 - val_loss: 4.2565e-04
# Epoch 22/50
# 63/63 [==============================] - 2s 32ms/step - loss: 5.7314e-04 - val_loss: 2.2447e-04
# Epoch 23/50
# 63/63 [==============================] - 2s 32ms/step - loss: 3.9575e-04 - val_loss: 2.7021e-04
# Epoch 24/50
# 63/63 [==============================] - 2s 33ms/step - loss: 3.9222e-04 - val_loss: 7.9070e-04
# Epoch 25/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.1433e-04 - val_loss: 1.5759e-04
# Epoch 26/50
# 63/63 [==============================] - 2s 33ms/step - loss: 3.7818e-04 - val_loss: 1.5835e-04
# Epoch 27/50
# 63/63 [==============================] - 2s 32ms/step - loss: 3.6523e-04 - val_loss: 1.8752e-04
# Epoch 28/50
# 63/63 [==============================] - 2s 34ms/step - loss: 3.7606e-04 - val_loss: 2.8056e-04
# Epoch 29/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.1387e-04 - val_loss: 4.6976e-04
# Epoch 30/50
# 63/63 [==============================] - 2s 32ms/step - loss: 4.2087e-04 - val_loss: 2.6655e-04
# Epoch 31/50
# 63/63 [==============================] - 2s 33ms/step - loss: 3.7844e-04 - val_loss: 1.6660e-04
# Epoch 32/50
# 63/63 [==============================] - 2s 33ms/step - loss: 3.9308e-04 - val_loss: 5.6285e-04
# Epoch 33/50
# 63/63 [==============================] - 2s 34ms/step - loss: 4.3111e-04 - val_loss: 2.4299e-04
# Epoch 34/50
# 63/63 [==============================] - 2s 33ms/step - loss: 3.9094e-04 - val_loss: 3.1154e-04
# Epoch 35/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.0490e-04 - val_loss: 1.5301e-04
# Epoch 36/50
# 63/63 [==============================] - 2s 33ms/step - loss: 3.6297e-04 - val_loss: 1.5267e-04
# Epoch 37/50
# 63/63 [==============================] - 2s 34ms/step - loss: 3.5563e-04 - val_loss: 2.5764e-04
# Epoch 38/50
# 63/63 [==============================] - 2s 33ms/step - loss: 3.6739e-04 - val_loss: 2.6180e-04
# Epoch 39/50
# 63/63 [==============================] - 2s 33ms/step - loss: 4.0751e-04 - val_loss: 1.8109e-04
# Epoch 40/50
# 63/63 [==============================] - 2s 34ms/step - loss: 2.9051e-04 - val_loss: 6.0648e-04
# Epoch 41/50
# 63/63 [==============================] - 2s 36ms/step - loss: 3.7738e-04 - val_loss: 1.8121e-04
# Epoch 42/50
# 63/63 [==============================] - 2s 34ms/step - loss: 3.5720e-04 - val_loss: 2.2533e-04
# Epoch 43/50
# 63/63 [==============================] - 2s 34ms/step - loss: 3.4098e-04 - val_loss: 1.6415e-04
# Epoch 44/50
# 63/63 [==============================] - 2s 34ms/step - loss: 4.4227e-04 - val_loss: 1.5791e-04
# Epoch 45/50
# 63/63 [==============================] - 2s 35ms/step - loss: 3.5583e-04 - val_loss: 0.0010
# Epoch 46/50
# 63/63 [==============================] - 2s 35ms/step - loss: 4.1271e-04 - val_loss: 1.8781e-04
# Epoch 47/50
# 63/63 [==============================] - 2s 35ms/step - loss: 4.3497e-04 - val_loss: 2.1060e-04
# Epoch 48/50
# 63/63 [==============================] - 2s 35ms/step - loss: 3.7208e-04 - val_loss: 3.6528e-04
# Epoch 49/50
# 63/63 [==============================] - 2s 35ms/step - loss: 3.4549e-04 - val_loss: 2.3724e-04
# Epoch 50/50
# 63/63 [==============================] - 2s 34ms/step - loss: 3.8207e-04 - val_loss: 2.1849e-04
# Standard Deviation of Error :  0.21508984486957336
# Denormalised Standard Deviation :  707.2046554389137
# Ratio of Standard Deviation of Error to Standard Deviation of Stock Price :  1.0954654709782023
# Train Score: 0.00031069 MSE (0.01762653 RMSE)
# Test Score: 0.00188070 MSE (0.04336702 RMSE)
