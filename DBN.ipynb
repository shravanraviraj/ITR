# %%
import torch
import torch.nn as nn
import numpy as np
import math
from torch.utils.data import DataLoader

# %%
class RBM(nn.Module):
    
    def __init__(self, visible_units = 50, hidden_units = 10, k=1, batch_size = 128, learning_rate = 1e-5, 
                 learning_rate_decay = False, increase_to_cd_k = False, device ='cpu'):
        
        super(RBM, self).__init__()
        self.desc = "RBM"
        self.visible_units = visible_units
        self.hidden_units = hidden_units
        self.k = k
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.increase_to_cd_k = increase_to_cd_k
        self.learning_rate = learning_rate
        self.learning_rate_decay = learning_rate_decay
        self.device = device
        
        self.activation = torch.nn.Sigmoid()
        self.activation_name = self.activation.__class__.__name__.lower()
        self.weight = nn.Parameter(torch.rand(self.visible_units, self.hidden_units, device = self.device))
        self.v_bias = nn.Parameter(torch.rand(self.visible_units, device = self.device))
        #self.h_bias = nn.Parameter(torch.rand(self.visible_units, device = self.device))
        self.h_bias = nn.Parameter(torch.rand(self.hidden_units, device = self.device))
        
        self.reset_parameters()
    
    def reset_parameters(self):
        nn.init.xavier_uniform_(self.weight, nn.init.calculate_gain(self.activation_name))
        nn.init.zeros_(self.v_bias)
        nn.init.zeros_(self.h_bias)
        
    def to_hidden(self, vis_prob):
        hid_prob = torch.matmul(vis_prob, self.weight)
        hid_prob = torch.add(hid_prob, self.h_bias)
        hid_prob = self.activation(hid_prob)
        hid_sample = torch.bernoulli(hid_prob)
        return hid_prob, hid_sample
    
    def to_visible(self, hid_prob):
        vis_prob_recon = torch.matmul(hid_prob,self.weight.t())
        vis_prob_recon = torch.add(vis_prob_recon, self.v_bias)
        vis_prob_recon = self.activation(vis_prob_recon)
        vis_sample = torch.bernoulli(vis_prob_recon)
        return vis_prob_recon, vis_sample
    
    #def reconstruction_error(self, data):
     #   return self.contrastive_divergence(data, False)
    
    def reconstruct(self, vis_prob, n_gibbs):
        vis_sample = torch.rand(vis_prob.size(), device=self.device)
        for i in range(n_gibbs):
            hid_prob, hid_sample = self.to_hidden(vis_prob)
            vis_prob, vis_sample = self.to_visible(hid_prob)
        return vis_prob, vis_sample
    
    def contrastive_divergence(self, input_data, training = True, n_gibbs_sampling_steps =1, lr = 0.001):
        #positive phase
        positive_hid_prob, positive_hid_dis = self.to_hidden(input_data)
        
        #calc energy via positive side
        positive_associations = torch.matmul(input_data.t(), positive_hid_dis)
        
        #Negative Phase
        hidden_activations = positive_hid_dis
        vis_probvis_prob = torch.rand(input_data.size(), device=self.device)
        hid_prob = torch.rand(positive_hid_prob.size(), device=self.device)
        
        for i in range(n_gibbs_sampling_steps):
            vis_prob, _ = self.to_visible(hidden_activations)
            hid_prob, hidden_activations = self.to_hidden(vis_prob)
        
        negative_vis_prob = vis_prob
        negative_hid_prob = hid_prob
        
        #Calculating w via negative side.
        negative_associations = torch.matmul(negative_vis_prob.t(), negative_hid_prob)
        
        # Update parameters
        grad_update = 0
        if training:
            batch_size = self.batch_size
            g = positive_associations - negative_associations
            grad_update = g / batch_size
            v_bias_update = (torch.sum(input_data - negative_vis_prob, dim=0) /
                             batch_size)
            h_bias_update = torch.sum(positive_hid_prob - negative_hid_prob,
                                      dim=0) / batch_size

            # Attention: While applying in-place operation to a leaf Variable,
            # .data should be added.
            
            self.weight.data += lr * grad_update
            self.v_bias.data += lr * v_bias_update
            self.h_bias.data += lr * h_bias_update

        # Compute reconstruction mse error
        error = torch.mean(torch.sum(
            (input_data - negative_vis_prob) ** 2, dim=0)).item()
        
        return error, torch.sum(torch.abs(grad_update)).item()
    
    def forward(self, input_data):
        return self.to_hidden(input_data)

    def step(self, input_data, epoch_i, epoch):
        
        # Gibbs_sampling step gradually increases to k as the train processes.
        if self.increase_to_cd_k:
            n_gibbs_sampling_steps = int(math.ceil((epoch_i / epoch) * self.k))
        else:
            n_gibbs_sampling_steps = self.k

        if self.learning_rate_decay:
            lr = self.learning_rate / epoch_i
        else:
            lr = self.learning_rate
        return self.contrastive_divergence(input_data, True, n_gibbs_sampling_steps, lr)

    
    def train_rbm(self, train_dataloader, epoch=50):

        if isinstance(train_dataloader, DataLoader):
            train_loader = train_dataloader
        else:
            raise TypeError('train_dataloader is not a dataloader instance.')

        for epoch_i in range(1, epoch + 1):
            n_batches = int(len(train_loader))

            cost_ = torch.FloatTensor(n_batches, 1)
            grad_ = torch.FloatTensor(n_batches, 1)

            # Train_loader contains input and output data. However, training
            # of RBM doesn't require output data.
            for i, batch in enumerate(train_loader):
                cost_[i - 1], grad_[i - 1] = self.step(batch[0], epoch_i, epoch)
            print('Epoch:{0}/{1} -rbm_train_loss: {2:.3f}'.format(epoch_i, epoch, torch.mean(cost_)))

        return

# %%
import warnings
import numpy as np
from torch.utils.data import TensorDataset, DataLoader, Dataset
from torch.optim import Adam, SGD

# %%
class DBN(nn.Module):
    def __init__(self, hidden_units, visible_units=256, output_units=1, k=2,learning_rate=1e-5, learning_rate_decay=False,
                 increase_to_cd_k=False, device='cpu'):
        
        super(DBN, self).__init__()
        self.n_layers = len(hidden_units)
        self.rbm_layers = []
        self.rbm_nodes = []
        self.device = device
        self.is_pretrained = False
        self.is_finetune = False

        # Creating different RBM layers
        for i in range(self.n_layers):
            if i == 0:
                input_size = visible_units
            else:
                input_size = hidden_units[i - 1]
            rbm = RBM(visible_units=input_size, hidden_units=hidden_units[i],k=k, learning_rate=learning_rate, learning_rate_decay=learning_rate_decay,
                      increase_to_cd_k=increase_to_cd_k, device=device)

            self.rbm_layers.append(rbm)

        self.W_rec = [self.rbm_layers[i].weight for i in range(self.n_layers)]
        self.bias_rec = [self.rbm_layers[i].h_bias for i in range(self.n_layers)]

        for i in range(self.n_layers):
            self.register_parameter('W_rec%i' % i, self.W_rec[i])
            self.register_parameter('bias_rec%i' % i, self.bias_rec[i])

        self.bpnn = torch.nn.Linear(hidden_units[-1], output_units).to(self.device)

    def forward(self, input_data):

        v = input_data.to(self.device)
        hid_output = v.clone()
        for i in range(len(self.rbm_layers)):
            hid_output, _ = self.rbm_layers[i].to_hidden(hid_output)
        output = self.bpnn(hid_output)
        return output

    def reconstruct(self, input_data):

        h = input_data.to(self.device)
        p_h = 0
        for i in range(len(self.rbm_layers)):
            # h = h.view((h.shape[0], -1))
            p_h, h = self.rbm_layers[i].to_hidden(h)

        for i in range(len(self.rbm_layers) - 1, -1, -1):
            # h = h.view((h.shape[0], -1))
            p_h, h = self.rbm_layers[i].to_visible(h)
        return p_h, h

    def pretrain(self, x, epoch=50, batch_size=10):

        hid_output_i = torch.tensor(x, dtype=torch.float, device=self.device)

        for i in range(len(self.rbm_layers)):
            print("Training rbm layer {}.".format(i + 1))

            dataset_i = TensorDataset(hid_output_i)
            dataloader_i = DataLoader(dataset_i, batch_size=batch_size, drop_last=False)

            self.rbm_layers[i].train_rbm(dataloader_i, epoch)
            hid_output_i, _ = self.rbm_layers[i].forward(hid_output_i)

        # Set pretrain finish flag.
        self.is_pretrained = True
        return

    def pretrain_single(self, x, layer_loc, epoch, batch_size):

        if layer_loc > len(self.rbm_layers) or layer_loc <= 0:
            raise ValueError('Layer index out of range.')
        ith_layer = layer_loc - 1
        hid_output_i = torch.tensor(x, dtype=torch.float, device=self.device)

        for ith in range(ith_layer):
            hid_output_i, _ = self.rbm_layers[ith].forward(hid_output_i)

        dataset_i = TensorDataset(hid_output_i)
        dataloader_i = DataLoader(dataset_i, batch_size=batch_size, drop_last=False)

        self.rbm_layers[ith_layer].train_rbm(dataloader_i, epoch)
        hid_output_i, _ = self.rbm_layers[ith_layer].forward(hid_output_i)
        return

    def finetune(self, x, y, epoch, batch_size, loss_function, optimizer, shuffle=False):

        if not self.is_pretrained:
            warnings.warn("Hasn't pretrained DBN model yet. Recommend "
                          "run self.pretrain() first.", RuntimeWarning)

        dataset = FineTuningDataset(x, y)
        dataloader = DataLoader(dataset, batch_size, shuffle=shuffle)

        print('Begin fine-tuning.')
        for epoch_i in range(1, epoch + 1):
            total_loss = 0
            for batch in dataloader:
                input_data, ground_truth = batch
                input_data = input_data.to(self.device)
                ground_truth = ground_truth.to(self.device)
                output = self.forward(input_data).flatten()
                loss = loss_function(ground_truth, output)
                # print(list(self.parameters()))
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                total_loss += loss.item()

            # Display train information
            if total_loss >= 1e-4:
                disp = '{2:.4f}'
            else:
                disp = '{2:.3e}'

            print(('Epoch:{0}/{1} -rbm_train_loss: ' + disp).format(epoch_i, epoch, total_loss))

        self.is_finetune = True

        return

    def predict(self, x, batch_size, shuffle=False):

        if not self.is_pretrained:
            warnings.warn("Hasn't pretrained DBN model yet. Recommend "
                          "run self.pretrain() first.", RuntimeWarning)

        if not self.is_pretrained:
            warnings.warn("Hasn't finetuned DBN model yet. Recommend "
                          "run self.finetune() first.", RuntimeWarning)
        y_predict = torch.tensor([])

        x_tensor = torch.tensor(x, dtype=torch.float, device=self.device)
        dataset = TensorDataset(x_tensor)
        dataloader = DataLoader(dataset, batch_size, shuffle)
        with torch.no_grad():
            for batch in dataloader:
                y = self.forward(batch[0])
                y_predict = torch.cat((y_predict, y.cpu()), 0)

        return y_predict.flatten()


class FineTuningDataset(Dataset):

    def __init__(self, x, y):
        self.x = x.astype(np.float32)
        self.y = y.astype(np.float32)

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return len(self.x)

# %%
from sklearn.preprocessing import *
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel("/home/shravan/Desktop/Datasets/pharma/pfizer/pfizer.xlsx")

print(df.head())
print("\n****\n",df.tail())

print("_________________________________________________________\n\nOPEN \n\tAverage : ",np.mean(df.loc[:]['Open']),"\n\tMaximum : ", np.max(df['Open']),"\n\tMinimum : ", np.min(df['Open']),"\n\tStandard Deviation : ", np.std(df['Open']))
print("\n\nHIGH \n\tAverage : ",np.mean(df.loc[:]['High']),"\n\tMaximum : ", np.max(df['High']),"\n\tMinimum : ", np.min(df['High']),"\n\tStandard Deviation : ", np.std(df['High']))
print("\n\nLOW \n\tAverage : ",np.mean(df.loc[:]['Low']),"\n\tMaximum : ", np.max(df['Low']),"\n\tMinimum : ", np.min(df['Low']),"\n\tStandard Deviation : ", np.std(df['Low']))
print("\n\nCLOSE \n\tAverage : ",np.mean(df.loc[:]['Close']),"\n\tMaximum : ", np.max(df['Close']),"\n\tMinimum : ", np.min(df['Close']),"\n\tStandard Deviation : ", np.std(df['Close']))
print("\n\nVOLUME \n\tAverage : ",np.mean(df.loc[:]['Volume']),"\n\tMaximum : ", np.max(df['Volume']),"\n\tMinimum : ", np.min(df['Volume']),"\n\tStandard Deviation : ", np.std(df['Volume']))

def reverse_data(df):
    date = []
    day = []
    open = []
    high = []
    low = []
    close = []
    volume = []
    for i in range(len(df)-1, -1, -1):
        #day.append((len(df)-1)-i)
        #date.append(df.loc[i]['Date '])
        #open.append(df.loc[i]['Open'])
        #high.append(df.loc[i]['High'])
        #low.append(df.loc[i]['Low'])
        close.append(df.loc[i]['Close'])
        #volume.append(df.loc[i]['Volume'])
    stocks = pd.DataFrame()
    #stocks['Day'] = day
    #stocks['Date'] = date
    #stocks['Open'] = open
    #stocks['High'] = high
    #stocks['Low'] = low
    stocks['Close'] = close
    #stocks['Volume'] = volume
    return stocks

stocks = reverse_data(df)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (30,10)
fig,ax = plt.subplots()

#ax.plot(stocks['Day'],stocks['Close'])
ax.plot(stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Pfizer Limited")
plt.show()
# Out:
#          Date     Open     High      Low    Close  Volume
# 0  29-Mar-2019  3300.0  3348.00  3265.00  3326.00   33841
# 1  28-Mar-2019  3251.0  3321.00  3230.00  3290.25   22424
# 2  27-Mar-2019  3220.6  3287.95  3191.05  3267.10   26351
# 3  26-Mar-2019  3165.0  3287.95  3144.00  3230.00   31056
# 4  25-Mar-2019  3166.0  3200.05  3135.00  3180.65   15472
#
# ****
#              Date     Open   High     Low   Close  Volume
# 2717  07-Apr-2008  672.35  694.5  662.15  685.90    5877
# 2718  04-Apr-2008  673.00  684.5  669.00  672.35   14869
# 2719  03-Apr-2008  675.00  691.8  669.10  684.05   11378
# 2720  02-Apr-2008  695.10  720.0  691.00  700.35   16497
# 2721  01-Apr-2008  700.00  700.0  675.00  694.70   14215
# _________________________________________________________
#
# OPEN
# 	Average :  1502.7655951506233
# 	Maximum :  3735.0
# 	Minimum :  450.0
# 	Standard Deviation :  646.3160392814301
#
#
# HIGH
# 	Average :  1524.758082292438
# 	Maximum :  3847.7
# 	Minimum :  454.1
# 	Standard Deviation :  655.7471248643697
#
#
# LOW
# 	Average :  1479.7705547391574
# 	Maximum :  3597.55
# 	Minimum :  435.0
# 	Standard Deviation :  634.510703479229
#
#
# CLOSE
# 	Average :  1501.0212711241725
# 	Maximum :  3731.9
# 	Minimum :  443.95
# 	Standard Deviation :  645.5745746211528
#
#
# VOLUME
# 	Average :  17575.136664217487
# 	Maximum :  645040
# 	Minimum :  75
# 	Standard Deviation :  36688.790495527
#     Close
# 0  694.70
# 1  700.35
# 2  684.05
# 3  672.35
# 4  685.90
#
# ****
#          Close
# 2717  3180.65
# 2718  3230.00
# 2719  3267.10
# 2720  3290.25
# 2721  3326.00

# %%
from sklearn.preprocessing import MinMaxScaler

def get_normalised_data(data):
    scaler = MinMaxScaler()
    #numerical = ['Open','High','Low','Close','Volume']
    numerical = ['Close']
    data[numerical] = scaler.fit_transform(data[numerical])
    return data

stocks = get_normalised_data(stocks)

print(stocks.head())
print("\n****\n",stocks.tail())

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20,10)
fig,ax = plt.subplots()

#ax.plot(stocks['Day'],stocks['Close'])
ax.plot(stocks['Close'])
plt.xlabel("Trading days")
plt.ylabel("Price")
plt.title("Pfizer Limited")
plt.show()
# Out:
#       Close
# 0  0.076263
# 1  0.077982
# 2  0.073024
# 3  0.069466
# 4  0.073587
#
# ****
#           Close
# 2717  0.832342
# 2718  0.847352
# 2719  0.858635
# 2720  0.865676
# 2721  0.876549

# %%
def unroll(stocks,unroll_length):
    result = []
    for i in range(len(stocks)-unroll_length+1):
        result.append(stocks[i : (i+unroll_length)])
    return np.asarray(result)

def train_test_split(stocks,unroll_length,prediction_size,prediction_time):
    x_test_start = prediction_size + prediction_time + unroll_length - 1
    
    #train data
    x_train = stocks[0 : (-x_test_start - prediction_time)].to_numpy()
    y_train = stocks[ (unroll_length - 1 + prediction_time) : -x_test_start]['Close'].to_numpy()
    
    #test_data
    x_test = stocks[-x_test_start : -prediction_time].to_numpy()
    y_test = stocks[-prediction_size:]['Close'].to_numpy()

    
    return x_train,x_test,y_train,y_test

prediction_size = 494
prediction_time = 5
unroll_length = 50

x_train,x_test,y_train,y_test = train_test_split(stocks,unroll_length,prediction_size,prediction_time)

x_train = unroll(x_train,unroll_length).reshape(2120,50)
x_test = unroll(x_test,unroll_length).reshape(494,50)

x_train = x_train.astype('float64')
y_train = y_train.astype('float64')
x_test = x_test.astype('float64')
y_test = y_test.astype('float64')


print("x_train", x_train.shape)
#print(x_train[0:2])
print("y_train", y_train.shape)
print("x_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (2120, 50)
# y_train (2120,)
# x_test (494, 50)
# y_test (494,)

# %%
input_length = 50
output_length = 1
test_percentage = 0.2

# network
hidden_units = [40, 40]
device = 'cpu'

if device == 'cuda':
    assert torch.cuda.is_available() is True, "cuda isn't available"
    print('Using GPU backend.\n'
          'GPU type: {}'.format(torch.cuda.get_device_name(0)))
else:
    print('Using CPU backend.')

# train & predict
batch_size = 128
epoch_pretrain = 300
epoch_finetune = 500
loss_function = torch.nn.MSELoss()
optimizer = torch.optim.Adam


dbn = DBN(hidden_units, input_length, output_length, device=device)

# Train model
dbn.pretrain(x_train, epoch=epoch_pretrain, batch_size=batch_size)
dbn.finetune(x_train, y_train, epoch_finetune, batch_size, loss_function, optimizer(dbn.parameters()))

# Make prediction and plot
y_predict = dbn.predict(x_test, batch_size)
#y_real = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
#y_predict = scaler.inverse_transform(y_predict.reshape(-1, 1)).flatten()
plt.figure(1)
#plt.plot(y_real, label='real')
plt.plot(y_predict, label='prediction')
plt.plot(y_test,"r-")
#plt.xlabel('MSE Error: {}'.format(mean_squared_error(y_real, y_predict)))
plt.legend()
plt.title('Prediction result')
plt.show()
# Out:
# Using CPU backend.
# Training rbm layer 1.
# Epoch:1/300 -rbm_train_loss: 13.784
# Epoch:2/300 -rbm_train_loss: 13.755
# Epoch:3/300 -rbm_train_loss: 13.726
# Epoch:4/300 -rbm_train_loss: 13.792
# Epoch:5/300 -rbm_train_loss: 13.665
# Epoch:6/300 -rbm_train_loss: 13.653
# Epoch:7/300 -rbm_train_loss: 13.645
# Epoch:8/300 -rbm_train_loss: 13.685
# Epoch:9/300 -rbm_train_loss: 13.690
# Epoch:10/300 -rbm_train_loss: 13.658
# Epoch:11/300 -rbm_train_loss: 13.643
# Epoch:12/300 -rbm_train_loss: 13.712
# Epoch:13/300 -rbm_train_loss: 13.615
# Epoch:14/300 -rbm_train_loss: 13.652
# Epoch:15/300 -rbm_train_loss: 13.615
# Epoch:16/300 -rbm_train_loss: 13.642
# Epoch:17/300 -rbm_train_loss: 13.561
# Epoch:18/300 -rbm_train_loss: 13.598
# Epoch:19/300 -rbm_train_loss: 13.562
# Epoch:20/300 -rbm_train_loss: 13.539
# Epoch:21/300 -rbm_train_loss: 13.553
# Epoch:22/300 -rbm_train_loss: 13.523
# Epoch:23/300 -rbm_train_loss: 13.516
# Epoch:24/300 -rbm_train_loss: 13.551
# Epoch:25/300 -rbm_train_loss: 13.541
# Epoch:26/300 -rbm_train_loss: 13.497
# Epoch:27/300 -rbm_train_loss: 13.490
# Epoch:28/300 -rbm_train_loss: 13.470
# Epoch:29/300 -rbm_train_loss: 13.481
# Epoch:30/300 -rbm_train_loss: 13.412
# Epoch:31/300 -rbm_train_loss: 13.471
# Epoch:32/300 -rbm_train_loss: 13.452
# Epoch:33/300 -rbm_train_loss: 13.424
# Epoch:34/300 -rbm_train_loss: 13.439
# Epoch:35/300 -rbm_train_loss: 13.397
# Epoch:36/300 -rbm_train_loss: 13.383
# Epoch:37/300 -rbm_train_loss: 13.356
# Epoch:38/300 -rbm_train_loss: 13.427
# Epoch:39/300 -rbm_train_loss: 13.360
# Epoch:40/300 -rbm_train_loss: 13.342
# Epoch:41/300 -rbm_train_loss: 13.352
# Epoch:42/300 -rbm_train_loss: 13.312
# Epoch:43/300 -rbm_train_loss: 13.348
# Epoch:44/300 -rbm_train_loss: 13.287
# Epoch:45/300 -rbm_train_loss: 13.327
# Epoch:46/300 -rbm_train_loss: 13.331
# Epoch:47/300 -rbm_train_loss: 13.308
# Epoch:48/300 -rbm_train_loss: 13.249
# Epoch:49/300 -rbm_train_loss: 13.264
# Epoch:50/300 -rbm_train_loss: 13.240
# Epoch:51/300 -rbm_train_loss: 13.310
# Epoch:52/300 -rbm_train_loss: 13.273
# Epoch:53/300 -rbm_train_loss: 13.220
# Epoch:54/300 -rbm_train_loss: 13.226
# Epoch:55/300 -rbm_train_loss: 13.247
# Epoch:56/300 -rbm_train_loss: 13.224
# Epoch:57/300 -rbm_train_loss: 13.227
# Epoch:58/300 -rbm_train_loss: 13.215
# Epoch:59/300 -rbm_train_loss: 13.190
# Epoch:60/300 -rbm_train_loss: 13.147
# Epoch:61/300 -rbm_train_loss: 13.133
# Epoch:62/300 -rbm_train_loss: 13.126
# Epoch:63/300 -rbm_train_loss: 13.232
# Epoch:64/300 -rbm_train_loss: 13.156
# Epoch:65/300 -rbm_train_loss: 13.114
# Epoch:66/300 -rbm_train_loss: 13.077
# Epoch:67/300 -rbm_train_loss: 13.127
# Epoch:68/300 -rbm_train_loss: 13.092
# Epoch:69/300 -rbm_train_loss: 13.109
# Epoch:70/300 -rbm_train_loss: 13.100
# Epoch:71/300 -rbm_train_loss: 13.048
# Epoch:72/300 -rbm_train_loss: 13.064
# Epoch:73/300 -rbm_train_loss: 13.034
# Epoch:74/300 -rbm_train_loss: 13.068
# Epoch:75/300 -rbm_train_loss: 13.029
# Epoch:76/300 -rbm_train_loss: 13.058
# Epoch:77/300 -rbm_train_loss: 12.995
# Epoch:78/300 -rbm_train_loss: 13.015
# Epoch:79/300 -rbm_train_loss: 13.003
# Epoch:80/300 -rbm_train_loss: 12.987
# Epoch:81/300 -rbm_train_loss: 12.968
# Epoch:82/300 -rbm_train_loss: 13.018
# Epoch:83/300 -rbm_train_loss: 12.959
# Epoch:84/300 -rbm_train_loss: 12.906
# Epoch:85/300 -rbm_train_loss: 12.937
# Epoch:86/300 -rbm_train_loss: 12.941
# Epoch:87/300 -rbm_train_loss: 12.932
# Epoch:88/300 -rbm_train_loss: 12.899
# Epoch:89/300 -rbm_train_loss: 12.886
# Epoch:90/300 -rbm_train_loss: 12.911
# Epoch:91/300 -rbm_train_loss: 12.881
# Epoch:92/300 -rbm_train_loss: 12.873
# Epoch:93/300 -rbm_train_loss: 12.909
# Epoch:94/300 -rbm_train_loss: 12.889
# Epoch:95/300 -rbm_train_loss: 12.848
# Epoch:96/300 -rbm_train_loss: 12.866
# Epoch:97/300 -rbm_train_loss: 12.847
# Epoch:98/300 -rbm_train_loss: 12.834
# Epoch:99/300 -rbm_train_loss: 12.836
# Epoch:100/300 -rbm_train_loss: 12.802
# Epoch:101/300 -rbm_train_loss: 12.822
# Epoch:102/300 -rbm_train_loss: 12.762
# Epoch:103/300 -rbm_train_loss: 12.789
# Epoch:104/300 -rbm_train_loss: 12.782
# Epoch:105/300 -rbm_train_loss: 12.769
# Epoch:106/300 -rbm_train_loss: 12.742
# Epoch:107/300 -rbm_train_loss: 12.750
# Epoch:108/300 -rbm_train_loss: 12.715
# Epoch:109/300 -rbm_train_loss: 12.719
# Epoch:110/300 -rbm_train_loss: 12.772
# Epoch:111/300 -rbm_train_loss: 12.706
# Epoch:112/300 -rbm_train_loss: 12.713
# Epoch:113/300 -rbm_train_loss: 12.658
# Epoch:114/300 -rbm_train_loss: 12.700
# Epoch:115/300 -rbm_train_loss: 12.696
# Epoch:116/300 -rbm_train_loss: 12.691
# Epoch:117/300 -rbm_train_loss: 12.685
# Epoch:118/300 -rbm_train_loss: 12.602
# Epoch:119/300 -rbm_train_loss: 12.642
# Epoch:120/300 -rbm_train_loss: 12.648
# Epoch:121/300 -rbm_train_loss: 12.649
# Epoch:122/300 -rbm_train_loss: 12.607
# Epoch:123/300 -rbm_train_loss: 12.603
# Epoch:124/300 -rbm_train_loss: 12.564
# Epoch:125/300 -rbm_train_loss: 12.563
# Epoch:126/300 -rbm_train_loss: 12.585
# Epoch:127/300 -rbm_train_loss: 12.566
# Epoch:128/300 -rbm_train_loss: 12.570
# Epoch:129/300 -rbm_train_loss: 12.568
# Epoch:130/300 -rbm_train_loss: 12.557
# Epoch:131/300 -rbm_train_loss: 12.571
# Epoch:132/300 -rbm_train_loss: 12.547
# Epoch:133/300 -rbm_train_loss: 12.532
# Epoch:134/300 -rbm_train_loss: 12.519
# Epoch:135/300 -rbm_train_loss: 12.509
# Epoch:136/300 -rbm_train_loss: 12.484
# Epoch:137/300 -rbm_train_loss: 12.487
# Epoch:138/300 -rbm_train_loss: 12.472
# Epoch:139/300 -rbm_train_loss: 12.468
# Epoch:140/300 -rbm_train_loss: 12.496
# Epoch:141/300 -rbm_train_loss: 12.439
# Epoch:142/300 -rbm_train_loss: 12.451
# Epoch:143/300 -rbm_train_loss: 12.477
# Epoch:144/300 -rbm_train_loss: 12.442
# Epoch:145/300 -rbm_train_loss: 12.413
# Epoch:146/300 -rbm_train_loss: 12.376
# Epoch:147/300 -rbm_train_loss: 12.405
# Epoch:148/300 -rbm_train_loss: 12.395
# Epoch:149/300 -rbm_train_loss: 12.397
# Epoch:150/300 -rbm_train_loss: 12.366
# Epoch:151/300 -rbm_train_loss: 12.405
# Epoch:152/300 -rbm_train_loss: 12.386
# Epoch:153/300 -rbm_train_loss: 12.379
# Epoch:154/300 -rbm_train_loss: 12.371
# Epoch:155/300 -rbm_train_loss: 12.351
# Epoch:156/300 -rbm_train_loss: 12.313
# Epoch:157/300 -rbm_train_loss: 12.305
# Epoch:158/300 -rbm_train_loss: 12.309
# Epoch:159/300 -rbm_train_loss: 12.314
# Epoch:160/300 -rbm_train_loss: 12.288
# Epoch:161/300 -rbm_train_loss: 12.311
# Epoch:162/300 -rbm_train_loss: 12.301
# Epoch:163/300 -rbm_train_loss: 12.294
# Epoch:164/300 -rbm_train_loss: 12.246
# Epoch:165/300 -rbm_train_loss: 12.236
# Epoch:166/300 -rbm_train_loss: 12.293
# Epoch:167/300 -rbm_train_loss: 12.239
# Epoch:168/300 -rbm_train_loss: 12.265
# Epoch:169/300 -rbm_train_loss: 12.256
# Epoch:170/300 -rbm_train_loss: 12.224
# Epoch:171/300 -rbm_train_loss: 12.247
# Epoch:172/300 -rbm_train_loss: 12.210
# Epoch:173/300 -rbm_train_loss: 12.202
# Epoch:174/300 -rbm_train_loss: 12.237
# Epoch:175/300 -rbm_train_loss: 12.177
# Epoch:176/300 -rbm_train_loss: 12.189
# Epoch:177/300 -rbm_train_loss: 12.176
# Epoch:178/300 -rbm_train_loss: 12.185
# Epoch:179/300 -rbm_train_loss: 12.175
# Epoch:180/300 -rbm_train_loss: 12.184
# Epoch:181/300 -rbm_train_loss: 12.168
# Epoch:182/300 -rbm_train_loss: 12.116
# Epoch:183/300 -rbm_train_loss: 12.169
# Epoch:184/300 -rbm_train_loss: 12.132
# Epoch:185/300 -rbm_train_loss: 12.092
# Epoch:186/300 -rbm_train_loss: 12.103
# Epoch:187/300 -rbm_train_loss: 12.119
# Epoch:188/300 -rbm_train_loss: 12.079
# Epoch:189/300 -rbm_train_loss: 12.081
# Epoch:190/300 -rbm_train_loss: 12.088
# Epoch:191/300 -rbm_train_loss: 12.060
# Epoch:192/300 -rbm_train_loss: 12.078
# Epoch:193/300 -rbm_train_loss: 12.049
# Epoch:194/300 -rbm_train_loss: 12.044
# Epoch:195/300 -rbm_train_loss: 12.038
# Epoch:196/300 -rbm_train_loss: 12.056
# Epoch:197/300 -rbm_train_loss: 12.051
# Epoch:198/300 -rbm_train_loss: 12.025
# Epoch:199/300 -rbm_train_loss: 12.024
# Epoch:200/300 -rbm_train_loss: 12.034
# Epoch:201/300 -rbm_train_loss: 11.982
# Epoch:202/300 -rbm_train_loss: 12.016
# Epoch:203/300 -rbm_train_loss: 11.977
# Epoch:204/300 -rbm_train_loss: 11.950
# Epoch:205/300 -rbm_train_loss: 11.946
# Epoch:206/300 -rbm_train_loss: 11.999
# Epoch:207/300 -rbm_train_loss: 11.921
# Epoch:208/300 -rbm_train_loss: 11.928
# Epoch:209/300 -rbm_train_loss: 11.949
# Epoch:210/300 -rbm_train_loss: 11.923
# Epoch:211/300 -rbm_train_loss: 11.892
# Epoch:212/300 -rbm_train_loss: 11.939
# Epoch:213/300 -rbm_train_loss: 11.887
# Epoch:214/300 -rbm_train_loss: 11.926
# Epoch:215/300 -rbm_train_loss: 11.875
# Epoch:216/300 -rbm_train_loss: 11.887
# Epoch:217/300 -rbm_train_loss: 11.854
# Epoch:218/300 -rbm_train_loss: 11.912
# Epoch:219/300 -rbm_train_loss: 11.861
# Epoch:220/300 -rbm_train_loss: 11.859
# Epoch:221/300 -rbm_train_loss: 11.855
# Epoch:222/300 -rbm_train_loss: 11.843
# Epoch:223/300 -rbm_train_loss: 11.876
# Epoch:224/300 -rbm_train_loss: 11.797
# Epoch:225/300 -rbm_train_loss: 11.860
# Epoch:226/300 -rbm_train_loss: 11.815
# Epoch:227/300 -rbm_train_loss: 11.810
# Epoch:228/300 -rbm_train_loss: 11.790
# Epoch:229/300 -rbm_train_loss: 11.788
# Epoch:230/300 -rbm_train_loss: 11.813
# Epoch:231/300 -rbm_train_loss: 11.775
# Epoch:232/300 -rbm_train_loss: 11.737
# Epoch:233/300 -rbm_train_loss: 11.765
# Epoch:234/300 -rbm_train_loss: 11.817
# Epoch:235/300 -rbm_train_loss: 11.766
# Epoch:236/300 -rbm_train_loss: 11.747
# Epoch:237/300 -rbm_train_loss: 11.766
# Epoch:238/300 -rbm_train_loss: 11.711
# Epoch:239/300 -rbm_train_loss: 11.761
# Epoch:240/300 -rbm_train_loss: 11.682
# Epoch:241/300 -rbm_train_loss: 11.690
# Epoch:242/300 -rbm_train_loss: 11.673
# Epoch:243/300 -rbm_train_loss: 11.710
# Epoch:244/300 -rbm_train_loss: 11.640
# Epoch:245/300 -rbm_train_loss: 11.697
# Epoch:246/300 -rbm_train_loss: 11.676
# Epoch:247/300 -rbm_train_loss: 11.660
# Epoch:248/300 -rbm_train_loss: 11.639
# Epoch:249/300 -rbm_train_loss: 11.693
# Epoch:250/300 -rbm_train_loss: 11.688
# Epoch:251/300 -rbm_train_loss: 11.608
# Epoch:252/300 -rbm_train_loss: 11.626
# Epoch:253/300 -rbm_train_loss: 11.647
# Epoch:254/300 -rbm_train_loss: 11.602
# Epoch:255/300 -rbm_train_loss: 11.625
# Epoch:256/300 -rbm_train_loss: 11.600
# Epoch:257/300 -rbm_train_loss: 11.576
# Epoch:258/300 -rbm_train_loss: 11.593
# Epoch:259/300 -rbm_train_loss: 11.580
# Epoch:260/300 -rbm_train_loss: 11.578
# Epoch:261/300 -rbm_train_loss: 11.588
# Epoch:262/300 -rbm_train_loss: 11.552
# Epoch:263/300 -rbm_train_loss: 11.561
# Epoch:264/300 -rbm_train_loss: 11.535
# Epoch:265/300 -rbm_train_loss: 11.518
# Epoch:266/300 -rbm_train_loss: 11.564
# Epoch:267/300 -rbm_train_loss: 11.548
# Epoch:268/300 -rbm_train_loss: 11.515
# Epoch:269/300 -rbm_train_loss: 11.515
# Epoch:270/300 -rbm_train_loss: 11.545
# Epoch:271/300 -rbm_train_loss: 11.522
# Epoch:272/300 -rbm_train_loss: 11.519
# Epoch:273/300 -rbm_train_loss: 11.484
# Epoch:274/300 -rbm_train_loss: 11.479
# Epoch:275/300 -rbm_train_loss: 11.461
# Epoch:276/300 -rbm_train_loss: 11.482
# Epoch:277/300 -rbm_train_loss: 11.449
# Epoch:278/300 -rbm_train_loss: 11.484
# Epoch:279/300 -rbm_train_loss: 11.493
# Epoch:280/300 -rbm_train_loss: 11.436
# Epoch:281/300 -rbm_train_loss: 11.418
# Epoch:282/300 -rbm_train_loss: 11.461
# Epoch:283/300 -rbm_train_loss: 11.433
# Epoch:284/300 -rbm_train_loss: 11.397
# Epoch:285/300 -rbm_train_loss: 11.439
# Epoch:286/300 -rbm_train_loss: 11.415
# Epoch:287/300 -rbm_train_loss: 11.402
# Epoch:288/300 -rbm_train_loss: 11.357
# Epoch:289/300 -rbm_train_loss: 11.386
# Epoch:290/300 -rbm_train_loss: 11.353
# Epoch:291/300 -rbm_train_loss: 11.384
# Epoch:292/300 -rbm_train_loss: 11.366
# Epoch:293/300 -rbm_train_loss: 11.388
# Epoch:294/300 -rbm_train_loss: 11.341
# Epoch:295/300 -rbm_train_loss: 11.369
# Epoch:296/300 -rbm_train_loss: 11.351
# Epoch:297/300 -rbm_train_loss: 11.316
# Epoch:298/300 -rbm_train_loss: 11.339
# Epoch:299/300 -rbm_train_loss: 11.318
# Epoch:300/300 -rbm_train_loss: 11.307
# Training rbm layer 2.
# Epoch:1/300 -rbm_train_loss: 5.360
# Epoch:2/300 -rbm_train_loss: 5.374
# Epoch:3/300 -rbm_train_loss: 5.368
# Epoch:4/300 -rbm_train_loss: 5.357
# Epoch:5/300 -rbm_train_loss: 5.345
# Epoch:6/300 -rbm_train_loss: 5.333
# Epoch:7/300 -rbm_train_loss: 5.341
# Epoch:8/300 -rbm_train_loss: 5.346
# Epoch:9/300 -rbm_train_loss: 5.356
# Epoch:10/300 -rbm_train_loss: 5.277
# Epoch:11/300 -rbm_train_loss: 5.297
# Epoch:12/300 -rbm_train_loss: 5.301
# Epoch:13/300 -rbm_train_loss: 5.316
# Epoch:14/300 -rbm_train_loss: 5.283
# Epoch:15/300 -rbm_train_loss: 5.333
# Epoch:16/300 -rbm_train_loss: 5.305
# Epoch:17/300 -rbm_train_loss: 5.307
# Epoch:18/300 -rbm_train_loss: 5.276
# Epoch:19/300 -rbm_train_loss: 5.294
# Epoch:20/300 -rbm_train_loss: 5.272
# Epoch:21/300 -rbm_train_loss: 5.265
# Epoch:22/300 -rbm_train_loss: 5.279
# Epoch:23/300 -rbm_train_loss: 5.265
# Epoch:24/300 -rbm_train_loss: 5.252
# Epoch:25/300 -rbm_train_loss: 5.268
# Epoch:26/300 -rbm_train_loss: 5.232
# Epoch:27/300 -rbm_train_loss: 5.260
# Epoch:28/300 -rbm_train_loss: 5.232
# Epoch:29/300 -rbm_train_loss: 5.249
# Epoch:30/300 -rbm_train_loss: 5.223
# Epoch:31/300 -rbm_train_loss: 5.233
# Epoch:32/300 -rbm_train_loss: 5.229
# Epoch:33/300 -rbm_train_loss: 5.219
# Epoch:34/300 -rbm_train_loss: 5.202
# Epoch:35/300 -rbm_train_loss: 5.229
# Epoch:36/300 -rbm_train_loss: 5.220
# Epoch:37/300 -rbm_train_loss: 5.236
# Epoch:38/300 -rbm_train_loss: 5.167
# Epoch:39/300 -rbm_train_loss: 5.179
# Epoch:40/300 -rbm_train_loss: 5.229
# Epoch:41/300 -rbm_train_loss: 5.212
# Epoch:42/300 -rbm_train_loss: 5.192
# Epoch:43/300 -rbm_train_loss: 5.185
# Epoch:44/300 -rbm_train_loss: 5.173
# Epoch:45/300 -rbm_train_loss: 5.192
# Epoch:46/300 -rbm_train_loss: 5.158
# Epoch:47/300 -rbm_train_loss: 5.159
# Epoch:48/300 -rbm_train_loss: 5.154
# Epoch:49/300 -rbm_train_loss: 5.188
# Epoch:50/300 -rbm_train_loss: 5.143
# Epoch:51/300 -rbm_train_loss: 5.148
# Epoch:52/300 -rbm_train_loss: 5.148
# Epoch:53/300 -rbm_train_loss: 5.138
# Epoch:54/300 -rbm_train_loss: 5.130
# Epoch:55/300 -rbm_train_loss: 5.148
# Epoch:56/300 -rbm_train_loss: 5.178
# Epoch:57/300 -rbm_train_loss: 5.148
# Epoch:58/300 -rbm_train_loss: 5.140
# Epoch:59/300 -rbm_train_loss: 5.133
# Epoch:60/300 -rbm_train_loss: 5.114
# Epoch:61/300 -rbm_train_loss: 5.126
# Epoch:62/300 -rbm_train_loss: 5.103
# Epoch:63/300 -rbm_train_loss: 5.116
# Epoch:64/300 -rbm_train_loss: 5.126
# Epoch:65/300 -rbm_train_loss: 5.097
# Epoch:66/300 -rbm_train_loss: 5.097
# Epoch:67/300 -rbm_train_loss: 5.098
# Epoch:68/300 -rbm_train_loss: 5.113
# Epoch:69/300 -rbm_train_loss: 5.092
# Epoch:70/300 -rbm_train_loss: 5.074
# Epoch:71/300 -rbm_train_loss: 5.052
# Epoch:72/300 -rbm_train_loss: 5.068
# Epoch:73/300 -rbm_train_loss: 5.088
# Epoch:74/300 -rbm_train_loss: 5.091
# Epoch:75/300 -rbm_train_loss: 5.063
# Epoch:76/300 -rbm_train_loss: 5.072
# Epoch:77/300 -rbm_train_loss: 5.028
# Epoch:78/300 -rbm_train_loss: 5.060
# Epoch:79/300 -rbm_train_loss: 5.048
# Epoch:80/300 -rbm_train_loss: 5.034
# Epoch:81/300 -rbm_train_loss: 5.027
# Epoch:82/300 -rbm_train_loss: 5.015
# Epoch:83/300 -rbm_train_loss: 5.034
# Epoch:84/300 -rbm_train_loss: 5.020
# Epoch:85/300 -rbm_train_loss: 4.993
# Epoch:86/300 -rbm_train_loss: 5.033
# Epoch:87/300 -rbm_train_loss: 5.014
# Epoch:88/300 -rbm_train_loss: 4.995
# Epoch:89/300 -rbm_train_loss: 4.994
# Epoch:90/300 -rbm_train_loss: 5.003
# Epoch:91/300 -rbm_train_loss: 5.028
# Epoch:92/300 -rbm_train_loss: 4.962
# Epoch:93/300 -rbm_train_loss: 4.996
# Epoch:94/300 -rbm_train_loss: 4.995
# Epoch:95/300 -rbm_train_loss: 4.969
# Epoch:96/300 -rbm_train_loss: 4.986
# Epoch:97/300 -rbm_train_loss: 4.955
# Epoch:98/300 -rbm_train_loss: 4.959
# Epoch:99/300 -rbm_train_loss: 4.935
# Epoch:100/300 -rbm_train_loss: 4.933
# Epoch:101/300 -rbm_train_loss: 4.970
# Epoch:102/300 -rbm_train_loss: 4.941
# Epoch:103/300 -rbm_train_loss: 4.936
# Epoch:104/300 -rbm_train_loss: 4.938
# Epoch:105/300 -rbm_train_loss: 4.950
# Epoch:106/300 -rbm_train_loss: 4.932
# Epoch:107/300 -rbm_train_loss: 4.935
# Epoch:108/300 -rbm_train_loss: 4.951
# Epoch:109/300 -rbm_train_loss: 4.924
# Epoch:110/300 -rbm_train_loss: 4.910
# Epoch:111/300 -rbm_train_loss: 4.884
# Epoch:112/300 -rbm_train_loss: 4.941
# Epoch:113/300 -rbm_train_loss: 4.912
# Epoch:114/300 -rbm_train_loss: 4.919
# Epoch:115/300 -rbm_train_loss: 4.881
# Epoch:116/300 -rbm_train_loss: 4.899
# Epoch:117/300 -rbm_train_loss: 4.884
# Epoch:118/300 -rbm_train_loss: 4.921
# Epoch:119/300 -rbm_train_loss: 4.888
# Epoch:120/300 -rbm_train_loss: 4.880
# Epoch:121/300 -rbm_train_loss: 4.891
# Epoch:122/300 -rbm_train_loss: 4.842
# Epoch:123/300 -rbm_train_loss: 4.853
# Epoch:124/300 -rbm_train_loss: 4.866
# Epoch:125/300 -rbm_train_loss: 4.840
# Epoch:126/300 -rbm_train_loss: 4.849
# Epoch:127/300 -rbm_train_loss: 4.856
# Epoch:128/300 -rbm_train_loss: 4.846
# Epoch:129/300 -rbm_train_loss: 4.871
# Epoch:130/300 -rbm_train_loss: 4.833
# Epoch:131/300 -rbm_train_loss: 4.821
# Epoch:132/300 -rbm_train_loss: 4.847
# Epoch:133/300 -rbm_train_loss: 4.811
# Epoch:134/300 -rbm_train_loss: 4.849
# Epoch:135/300 -rbm_train_loss: 4.821
# Epoch:136/300 -rbm_train_loss: 4.818
# Epoch:137/300 -rbm_train_loss: 4.826
# Epoch:138/300 -rbm_train_loss: 4.826
# Epoch:139/300 -rbm_train_loss: 4.817
# Epoch:140/300 -rbm_train_loss: 4.795
# Epoch:141/300 -rbm_train_loss: 4.834
# Epoch:142/300 -rbm_train_loss: 4.806
# Epoch:143/300 -rbm_train_loss: 4.787
# Epoch:144/300 -rbm_train_loss: 4.789
# Epoch:145/300 -rbm_train_loss: 4.798
# Epoch:146/300 -rbm_train_loss: 4.777
# Epoch:147/300 -rbm_train_loss: 4.775
# Epoch:148/300 -rbm_train_loss: 4.787
# Epoch:149/300 -rbm_train_loss: 4.779
# Epoch:150/300 -rbm_train_loss: 4.784
# Epoch:151/300 -rbm_train_loss: 4.774
# Epoch:152/300 -rbm_train_loss: 4.765
# Epoch:153/300 -rbm_train_loss: 4.739
# Epoch:154/300 -rbm_train_loss: 4.743
# Epoch:155/300 -rbm_train_loss: 4.774
# Epoch:156/300 -rbm_train_loss: 4.735
# Epoch:157/300 -rbm_train_loss: 4.777
# Epoch:158/300 -rbm_train_loss: 4.741
# Epoch:159/300 -rbm_train_loss: 4.717
# Epoch:160/300 -rbm_train_loss: 4.727
# Epoch:161/300 -rbm_train_loss: 4.724
# Epoch:162/300 -rbm_train_loss: 4.700
# Epoch:163/300 -rbm_train_loss: 4.733
# Epoch:164/300 -rbm_train_loss: 4.702
# Epoch:165/300 -rbm_train_loss: 4.692
# Epoch:166/300 -rbm_train_loss: 4.695
# Epoch:167/300 -rbm_train_loss: 4.702
# Epoch:168/300 -rbm_train_loss: 4.717
# Epoch:169/300 -rbm_train_loss: 4.710
# Epoch:170/300 -rbm_train_loss: 4.715
# Epoch:171/300 -rbm_train_loss: 4.704
# Epoch:172/300 -rbm_train_loss: 4.706
# Epoch:173/300 -rbm_train_loss: 4.682
# Epoch:174/300 -rbm_train_loss: 4.691
# Epoch:175/300 -rbm_train_loss: 4.692
# Epoch:176/300 -rbm_train_loss: 4.673
# Epoch:177/300 -rbm_train_loss: 4.690
# Epoch:178/300 -rbm_train_loss: 4.676
# Epoch:179/300 -rbm_train_loss: 4.647
# Epoch:180/300 -rbm_train_loss: 4.657
# Epoch:181/300 -rbm_train_loss: 4.679
# Epoch:182/300 -rbm_train_loss: 4.639
# Epoch:183/300 -rbm_train_loss: 4.647
# Epoch:184/300 -rbm_train_loss: 4.682
# Epoch:185/300 -rbm_train_loss: 4.674
# Epoch:186/300 -rbm_train_loss: 4.650
# Epoch:187/300 -rbm_train_loss: 4.649
# Epoch:188/300 -rbm_train_loss: 4.608
# Epoch:189/300 -rbm_train_loss: 4.641
# Epoch:190/300 -rbm_train_loss: 4.623
# Epoch:191/300 -rbm_train_loss: 4.612
# Epoch:192/300 -rbm_train_loss: 4.630
# Epoch:193/300 -rbm_train_loss: 4.612
# Epoch:194/300 -rbm_train_loss: 4.612
# Epoch:195/300 -rbm_train_loss: 4.618
# Epoch:196/300 -rbm_train_loss: 4.596
# Epoch:197/300 -rbm_train_loss: 4.591
# Epoch:198/300 -rbm_train_loss: 4.602
# Epoch:199/300 -rbm_train_loss: 4.612
# Epoch:200/300 -rbm_train_loss: 4.602
# Epoch:201/300 -rbm_train_loss: 4.591
# Epoch:202/300 -rbm_train_loss: 4.592
# Epoch:203/300 -rbm_train_loss: 4.581
# Epoch:204/300 -rbm_train_loss: 4.596
# Epoch:205/300 -rbm_train_loss: 4.572
# Epoch:206/300 -rbm_train_loss: 4.576
# Epoch:207/300 -rbm_train_loss: 4.571
# Epoch:208/300 -rbm_train_loss: 4.574
# Epoch:209/300 -rbm_train_loss: 4.589
# Epoch:210/300 -rbm_train_loss: 4.553
# Epoch:211/300 -rbm_train_loss: 4.575
# Epoch:212/300 -rbm_train_loss: 4.534
# Epoch:213/300 -rbm_train_loss: 4.547
# Epoch:214/300 -rbm_train_loss: 4.536
# Epoch:215/300 -rbm_train_loss: 4.531
# Epoch:216/300 -rbm_train_loss: 4.521
# Epoch:217/300 -rbm_train_loss: 4.545
# Epoch:218/300 -rbm_train_loss: 4.534
# Epoch:219/300 -rbm_train_loss: 4.534
# Epoch:220/300 -rbm_train_loss: 4.558
# Epoch:221/300 -rbm_train_loss: 4.514
# Epoch:222/300 -rbm_train_loss: 4.534
# Epoch:223/300 -rbm_train_loss: 4.560
# Epoch:224/300 -rbm_train_loss: 4.500
# Epoch:225/300 -rbm_train_loss: 4.497
# Epoch:226/300 -rbm_train_loss: 4.526
# Epoch:227/300 -rbm_train_loss: 4.511
# Epoch:228/300 -rbm_train_loss: 4.541
# Epoch:229/300 -rbm_train_loss: 4.495
# Epoch:230/300 -rbm_train_loss: 4.494
# Epoch:231/300 -rbm_train_loss: 4.496
# Epoch:232/300 -rbm_train_loss: 4.498
# Epoch:233/300 -rbm_train_loss: 4.469
# Epoch:234/300 -rbm_train_loss: 4.462
# Epoch:235/300 -rbm_train_loss: 4.498
# Epoch:236/300 -rbm_train_loss: 4.479
# Epoch:237/300 -rbm_train_loss: 4.472
# Epoch:238/300 -rbm_train_loss: 4.448
# Epoch:239/300 -rbm_train_loss: 4.476
# Epoch:240/300 -rbm_train_loss: 4.442
# Epoch:241/300 -rbm_train_loss: 4.461
# Epoch:242/300 -rbm_train_loss: 4.434
# Epoch:243/300 -rbm_train_loss: 4.439
# Epoch:244/300 -rbm_train_loss: 4.454
# Epoch:245/300 -rbm_train_loss: 4.432
# Epoch:246/300 -rbm_train_loss: 4.443
# Epoch:247/300 -rbm_train_loss: 4.424
# Epoch:248/300 -rbm_train_loss: 4.445
# Epoch:249/300 -rbm_train_loss: 4.456
# Epoch:250/300 -rbm_train_loss: 4.453
# Epoch:251/300 -rbm_train_loss: 4.461
# Epoch:252/300 -rbm_train_loss: 4.431
# Epoch:253/300 -rbm_train_loss: 4.425
# Epoch:254/300 -rbm_train_loss: 4.437
# Epoch:255/300 -rbm_train_loss: 4.417
# Epoch:256/300 -rbm_train_loss: 4.393
# Epoch:257/300 -rbm_train_loss: 4.421
# Epoch:258/300 -rbm_train_loss: 4.400
# Epoch:259/300 -rbm_train_loss: 4.407
# Epoch:260/300 -rbm_train_loss: 4.408
# Epoch:261/300 -rbm_train_loss: 4.387
# Epoch:262/300 -rbm_train_loss: 4.396
# Epoch:263/300 -rbm_train_loss: 4.387
# Epoch:264/300 -rbm_train_loss: 4.397
# Epoch:265/300 -rbm_train_loss: 4.372
# Epoch:266/300 -rbm_train_loss: 4.372
# Epoch:267/300 -rbm_train_loss: 4.373
# Epoch:268/300 -rbm_train_loss: 4.391
# Epoch:269/300 -rbm_train_loss: 4.378
# Epoch:270/300 -rbm_train_loss: 4.395
# Epoch:271/300 -rbm_train_loss: 4.347
# Epoch:272/300 -rbm_train_loss: 4.375
# Epoch:273/300 -rbm_train_loss: 4.353
# Epoch:274/300 -rbm_train_loss: 4.360
# Epoch:275/300 -rbm_train_loss: 4.331
# Epoch:276/300 -rbm_train_loss: 4.341
# Epoch:277/300 -rbm_train_loss: 4.356
# Epoch:278/300 -rbm_train_loss: 4.321
# Epoch:279/300 -rbm_train_loss: 4.337
# Epoch:280/300 -rbm_train_loss: 4.336
# Epoch:281/300 -rbm_train_loss: 4.342
# Epoch:282/300 -rbm_train_loss: 4.331
# Epoch:283/300 -rbm_train_loss: 4.288
# Epoch:284/300 -rbm_train_loss: 4.340
# Epoch:285/300 -rbm_train_loss: 4.331
# Epoch:286/300 -rbm_train_loss: 4.327
# Epoch:287/300 -rbm_train_loss: 4.327
# Epoch:288/300 -rbm_train_loss: 4.318
# Epoch:289/300 -rbm_train_loss: 4.317
# Epoch:290/300 -rbm_train_loss: 4.310
# Epoch:291/300 -rbm_train_loss: 4.289
# Epoch:292/300 -rbm_train_loss: 4.347
# Epoch:293/300 -rbm_train_loss: 4.322
# Epoch:294/300 -rbm_train_loss: 4.302
# Epoch:295/300 -rbm_train_loss: 4.286
# Epoch:296/300 -rbm_train_loss: 4.304
# Epoch:297/300 -rbm_train_loss: 4.297
# Epoch:298/300 -rbm_train_loss: 4.287
# Epoch:299/300 -rbm_train_loss: 4.278
# Epoch:300/300 -rbm_train_loss: 4.259
# Begin fine-tuning.
# Epoch:1/500 -rbm_train_loss: 2.1047
# Epoch:2/500 -rbm_train_loss: 0.3197
# Epoch:3/500 -rbm_train_loss: 0.5420
# Epoch:4/500 -rbm_train_loss: 0.3379
# Epoch:5/500 -rbm_train_loss: 0.2878
# Epoch:6/500 -rbm_train_loss: 0.2891
# Epoch:7/500 -rbm_train_loss: 0.2520
# Epoch:8/500 -rbm_train_loss: 0.2266
# Epoch:9/500 -rbm_train_loss: 0.2042
# Epoch:10/500 -rbm_train_loss: 0.1812
# Epoch:11/500 -rbm_train_loss: 0.1610
# Epoch:12/500 -rbm_train_loss: 0.1425
# Epoch:13/500 -rbm_train_loss: 0.1258
# Epoch:14/500 -rbm_train_loss: 0.1109
# Epoch:15/500 -rbm_train_loss: 0.0979
# Epoch:16/500 -rbm_train_loss: 0.0866
# Epoch:17/500 -rbm_train_loss: 0.0768
# Epoch:18/500 -rbm_train_loss: 0.0686
# Epoch:19/500 -rbm_train_loss: 0.0617
# Epoch:20/500 -rbm_train_loss: 0.0561
# Epoch:21/500 -rbm_train_loss: 0.0515
# Epoch:22/500 -rbm_train_loss: 0.0478
# Epoch:23/500 -rbm_train_loss: 0.0448
# Epoch:24/500 -rbm_train_loss: 0.0425
# Epoch:25/500 -rbm_train_loss: 0.0407
# Epoch:26/500 -rbm_train_loss: 0.0393
# Epoch:27/500 -rbm_train_loss: 0.0381
# Epoch:28/500 -rbm_train_loss: 0.0372
# Epoch:29/500 -rbm_train_loss: 0.0365
# Epoch:30/500 -rbm_train_loss: 0.0358
# Epoch:31/500 -rbm_train_loss: 0.0352
# Epoch:32/500 -rbm_train_loss: 0.0347
# Epoch:33/500 -rbm_train_loss: 0.0343
# Epoch:34/500 -rbm_train_loss: 0.0338
# Epoch:35/500 -rbm_train_loss: 0.0334
# Epoch:36/500 -rbm_train_loss: 0.0330
# Epoch:37/500 -rbm_train_loss: 0.0327
# Epoch:38/500 -rbm_train_loss: 0.0323
# Epoch:39/500 -rbm_train_loss: 0.0320
# Epoch:40/500 -rbm_train_loss: 0.0317
# Epoch:41/500 -rbm_train_loss: 0.0314
# Epoch:42/500 -rbm_train_loss: 0.0311
# Epoch:43/500 -rbm_train_loss: 0.0308
# Epoch:44/500 -rbm_train_loss: 0.0305
# Epoch:45/500 -rbm_train_loss: 0.0302
# Epoch:46/500 -rbm_train_loss: 0.0300
# Epoch:47/500 -rbm_train_loss: 0.0297
# Epoch:48/500 -rbm_train_loss: 0.0295
# Epoch:49/500 -rbm_train_loss: 0.0292
# Epoch:50/500 -rbm_train_loss: 0.0290
# Epoch:51/500 -rbm_train_loss: 0.0288
# Epoch:52/500 -rbm_train_loss: 0.0285
# Epoch:53/500 -rbm_train_loss: 0.0283
# Epoch:54/500 -rbm_train_loss: 0.0281
# Epoch:55/500 -rbm_train_loss: 0.0279
# Epoch:56/500 -rbm_train_loss: 0.0277
# Epoch:57/500 -rbm_train_loss: 0.0275
# Epoch:58/500 -rbm_train_loss: 0.0273
# Epoch:59/500 -rbm_train_loss: 0.0271
# Epoch:60/500 -rbm_train_loss: 0.0269
# Epoch:61/500 -rbm_train_loss: 0.0267
# Epoch:62/500 -rbm_train_loss: 0.0265
# Epoch:63/500 -rbm_train_loss: 0.0264
# Epoch:64/500 -rbm_train_loss: 0.0262
# Epoch:65/500 -rbm_train_loss: 0.0260
# Epoch:66/500 -rbm_train_loss: 0.0258
# Epoch:67/500 -rbm_train_loss: 0.0257
# Epoch:68/500 -rbm_train_loss: 0.0255
# Epoch:69/500 -rbm_train_loss: 0.0253
# Epoch:70/500 -rbm_train_loss: 0.0252
# Epoch:71/500 -rbm_train_loss: 0.0250
# Epoch:72/500 -rbm_train_loss: 0.0249
# Epoch:73/500 -rbm_train_loss: 0.0247
# Epoch:74/500 -rbm_train_loss: 0.0245
# Epoch:75/500 -rbm_train_loss: 0.0244
# Epoch:76/500 -rbm_train_loss: 0.0242
# Epoch:77/500 -rbm_train_loss: 0.0241
# Epoch:78/500 -rbm_train_loss: 0.0240
# Epoch:79/500 -rbm_train_loss: 0.0238
# Epoch:80/500 -rbm_train_loss: 0.0237
# Epoch:81/500 -rbm_train_loss: 0.0235
# Epoch:82/500 -rbm_train_loss: 0.0234
# Epoch:83/500 -rbm_train_loss: 0.0233
# Epoch:84/500 -rbm_train_loss: 0.0231
# Epoch:85/500 -rbm_train_loss: 0.0230
# Epoch:86/500 -rbm_train_loss: 0.0229
# Epoch:87/500 -rbm_train_loss: 0.0227
# Epoch:88/500 -rbm_train_loss: 0.0226
# Epoch:89/500 -rbm_train_loss: 0.0225
# Epoch:90/500 -rbm_train_loss: 0.0224
# Epoch:91/500 -rbm_train_loss: 0.0222
# Epoch:92/500 -rbm_train_loss: 0.0221
# Epoch:93/500 -rbm_train_loss: 0.0220
# Epoch:94/500 -rbm_train_loss: 0.0219
# Epoch:95/500 -rbm_train_loss: 0.0218
# Epoch:96/500 -rbm_train_loss: 0.0217
# Epoch:97/500 -rbm_train_loss: 0.0216
# Epoch:98/500 -rbm_train_loss: 0.0214
# Epoch:99/500 -rbm_train_loss: 0.0213
# Epoch:100/500 -rbm_train_loss: 0.0212
# Epoch:101/500 -rbm_train_loss: 0.0211
# Epoch:102/500 -rbm_train_loss: 0.0210
# Epoch:103/500 -rbm_train_loss: 0.0209
# Epoch:104/500 -rbm_train_loss: 0.0208
# Epoch:105/500 -rbm_train_loss: 0.0207
# Epoch:106/500 -rbm_train_loss: 0.0206
# Epoch:107/500 -rbm_train_loss: 0.0205
# Epoch:108/500 -rbm_train_loss: 0.0204
# Epoch:109/500 -rbm_train_loss: 0.0203
# Epoch:110/500 -rbm_train_loss: 0.0202
# Epoch:111/500 -rbm_train_loss: 0.0201
# Epoch:112/500 -rbm_train_loss: 0.0200
# Epoch:113/500 -rbm_train_loss: 0.0199
# Epoch:114/500 -rbm_train_loss: 0.0198
# Epoch:115/500 -rbm_train_loss: 0.0197
# Epoch:116/500 -rbm_train_loss: 0.0197
# Epoch:117/500 -rbm_train_loss: 0.0196
# Epoch:118/500 -rbm_train_loss: 0.0195
# Epoch:119/500 -rbm_train_loss: 0.0194
# Epoch:120/500 -rbm_train_loss: 0.0193
# Epoch:121/500 -rbm_train_loss: 0.0192
# Epoch:122/500 -rbm_train_loss: 0.0191
# Epoch:123/500 -rbm_train_loss: 0.0190
# Epoch:124/500 -rbm_train_loss: 0.0189
# Epoch:125/500 -rbm_train_loss: 0.0188
# Epoch:126/500 -rbm_train_loss: 0.0187
# Epoch:127/500 -rbm_train_loss: 0.0186
# Epoch:128/500 -rbm_train_loss: 0.0185
# Epoch:129/500 -rbm_train_loss: 0.0184
# Epoch:130/500 -rbm_train_loss: 0.0183
# Epoch:131/500 -rbm_train_loss: 0.0182
# Epoch:132/500 -rbm_train_loss: 0.0181
# Epoch:133/500 -rbm_train_loss: 0.0180
# Epoch:134/500 -rbm_train_loss: 0.0179
# Epoch:135/500 -rbm_train_loss: 0.0178
# Epoch:136/500 -rbm_train_loss: 0.0177
# Epoch:137/500 -rbm_train_loss: 0.0176
# Epoch:138/500 -rbm_train_loss: 0.0175
# Epoch:139/500 -rbm_train_loss: 0.0174
# Epoch:140/500 -rbm_train_loss: 0.0172
# Epoch:141/500 -rbm_train_loss: 0.0171
# Epoch:142/500 -rbm_train_loss: 0.0170
# Epoch:143/500 -rbm_train_loss: 0.0169
# Epoch:144/500 -rbm_train_loss: 0.0168
# Epoch:145/500 -rbm_train_loss: 0.0166
# Epoch:146/500 -rbm_train_loss: 0.0165
# Epoch:147/500 -rbm_train_loss: 0.0164
# Epoch:148/500 -rbm_train_loss: 0.0163
# Epoch:149/500 -rbm_train_loss: 0.0161
# Epoch:150/500 -rbm_train_loss: 0.0160
# Epoch:151/500 -rbm_train_loss: 0.0159
# Epoch:152/500 -rbm_train_loss: 0.0157
# Epoch:153/500 -rbm_train_loss: 0.0156
# Epoch:154/500 -rbm_train_loss: 0.0155
# Epoch:155/500 -rbm_train_loss: 0.0153
# Epoch:156/500 -rbm_train_loss: 0.0152
# Epoch:157/500 -rbm_train_loss: 0.0150
# Epoch:158/500 -rbm_train_loss: 0.0149
# Epoch:159/500 -rbm_train_loss: 0.0148
# Epoch:160/500 -rbm_train_loss: 0.0146
# Epoch:161/500 -rbm_train_loss: 0.0145
# Epoch:162/500 -rbm_train_loss: 0.0143
# Epoch:163/500 -rbm_train_loss: 0.0142
# Epoch:164/500 -rbm_train_loss: 0.0140
# Epoch:165/500 -rbm_train_loss: 0.0139
# Epoch:166/500 -rbm_train_loss: 0.0138
# Epoch:167/500 -rbm_train_loss: 0.0136
# Epoch:168/500 -rbm_train_loss: 0.0135
# Epoch:169/500 -rbm_train_loss: 0.0134
# Epoch:170/500 -rbm_train_loss: 0.0132
# Epoch:171/500 -rbm_train_loss: 0.0131
# Epoch:172/500 -rbm_train_loss: 0.0130
# Epoch:173/500 -rbm_train_loss: 0.0129
# Epoch:174/500 -rbm_train_loss: 0.0128
# Epoch:175/500 -rbm_train_loss: 0.0127
# Epoch:176/500 -rbm_train_loss: 0.0126
# Epoch:177/500 -rbm_train_loss: 0.0125
# Epoch:178/500 -rbm_train_loss: 0.0124
# Epoch:179/500 -rbm_train_loss: 0.0123
# Epoch:180/500 -rbm_train_loss: 0.0122
# Epoch:181/500 -rbm_train_loss: 0.0122
# Epoch:182/500 -rbm_train_loss: 0.0121
# Epoch:183/500 -rbm_train_loss: 0.0121
# Epoch:184/500 -rbm_train_loss: 0.0120
# Epoch:185/500 -rbm_train_loss: 0.0120
# Epoch:186/500 -rbm_train_loss: 0.0119
# Epoch:187/500 -rbm_train_loss: 0.0119
# Epoch:188/500 -rbm_train_loss: 0.0119
# Epoch:189/500 -rbm_train_loss: 0.0119
# Epoch:190/500 -rbm_train_loss: 0.0118
# Epoch:191/500 -rbm_train_loss: 0.0118
# Epoch:192/500 -rbm_train_loss: 0.0118
# Epoch:193/500 -rbm_train_loss: 0.0118
# Epoch:194/500 -rbm_train_loss: 0.0118
# Epoch:195/500 -rbm_train_loss: 0.0118
# Epoch:196/500 -rbm_train_loss: 0.0118
# Epoch:197/500 -rbm_train_loss: 0.0118
# Epoch:198/500 -rbm_train_loss: 0.0118
# Epoch:199/500 -rbm_train_loss: 0.0118
# Epoch:200/500 -rbm_train_loss: 0.0118
# Epoch:201/500 -rbm_train_loss: 0.0118
# Epoch:202/500 -rbm_train_loss: 0.0118
# Epoch:203/500 -rbm_train_loss: 0.0118
# Epoch:204/500 -rbm_train_loss: 0.0118
# Epoch:205/500 -rbm_train_loss: 0.0118
# Epoch:206/500 -rbm_train_loss: 0.0118
# Epoch:207/500 -rbm_train_loss: 0.0118
# Epoch:208/500 -rbm_train_loss: 0.0118
# Epoch:209/500 -rbm_train_loss: 0.0118
# Epoch:210/500 -rbm_train_loss: 0.0119
# Epoch:211/500 -rbm_train_loss: 0.0119
# Epoch:212/500 -rbm_train_loss: 0.0119
# Epoch:213/500 -rbm_train_loss: 0.0119
# Epoch:214/500 -rbm_train_loss: 0.0119
# Epoch:215/500 -rbm_train_loss: 0.0119
# Epoch:216/500 -rbm_train_loss: 0.0119
# Epoch:217/500 -rbm_train_loss: 0.0119
# Epoch:218/500 -rbm_train_loss: 0.0119
# Epoch:219/500 -rbm_train_loss: 0.0119
# Epoch:220/500 -rbm_train_loss: 0.0119
# Epoch:221/500 -rbm_train_loss: 0.0120
# Epoch:222/500 -rbm_train_loss: 0.0120
# Epoch:223/500 -rbm_train_loss: 0.0120
# Epoch:224/500 -rbm_train_loss: 0.0120
# Epoch:225/500 -rbm_train_loss: 0.0120
# Epoch:226/500 -rbm_train_loss: 0.0120
# Epoch:227/500 -rbm_train_loss: 0.0120
# Epoch:228/500 -rbm_train_loss: 0.0121
# Epoch:229/500 -rbm_train_loss: 0.0121
# Epoch:230/500 -rbm_train_loss: 0.0121
# Epoch:231/500 -rbm_train_loss: 0.0121
# Epoch:232/500 -rbm_train_loss: 0.0122
# Epoch:233/500 -rbm_train_loss: 0.0122
# Epoch:234/500 -rbm_train_loss: 0.0122
# Epoch:235/500 -rbm_train_loss: 0.0123
# Epoch:236/500 -rbm_train_loss: 0.0123
# Epoch:237/500 -rbm_train_loss: 0.0123
# Epoch:238/500 -rbm_train_loss: 0.0124
# Epoch:239/500 -rbm_train_loss: 0.0124
# Epoch:240/500 -rbm_train_loss: 0.0125
# Epoch:241/500 -rbm_train_loss: 0.0125
# Epoch:242/500 -rbm_train_loss: 0.0126
# Epoch:243/500 -rbm_train_loss: 0.0126
# Epoch:244/500 -rbm_train_loss: 0.0127
# Epoch:245/500 -rbm_train_loss: 0.0128
# Epoch:246/500 -rbm_train_loss: 0.0128
# Epoch:247/500 -rbm_train_loss: 0.0129
# Epoch:248/500 -rbm_train_loss: 0.0130
# Epoch:249/500 -rbm_train_loss: 0.0131
# Epoch:250/500 -rbm_train_loss: 0.0132
# Epoch:251/500 -rbm_train_loss: 0.0133
# Epoch:252/500 -rbm_train_loss: 0.0134
# Epoch:253/500 -rbm_train_loss: 0.0135
# Epoch:254/500 -rbm_train_loss: 0.0136
# Epoch:255/500 -rbm_train_loss: 0.0137
# Epoch:256/500 -rbm_train_loss: 0.0139
# Epoch:257/500 -rbm_train_loss: 0.0140
# Epoch:258/500 -rbm_train_loss: 0.0142
# Epoch:259/500 -rbm_train_loss: 0.0143
# Epoch:260/500 -rbm_train_loss: 0.0145
# Epoch:261/500 -rbm_train_loss: 0.0147
# Epoch:262/500 -rbm_train_loss: 0.0149
# Epoch:263/500 -rbm_train_loss: 0.0152
# Epoch:264/500 -rbm_train_loss: 0.0154
# Epoch:265/500 -rbm_train_loss: 0.0157
# Epoch:266/500 -rbm_train_loss: 0.0160
# Epoch:267/500 -rbm_train_loss: 0.0163
# Epoch:268/500 -rbm_train_loss: 0.0166
# Epoch:269/500 -rbm_train_loss: 0.0170
# Epoch:270/500 -rbm_train_loss: 0.0173
# Epoch:271/500 -rbm_train_loss: 0.0178
# Epoch:272/500 -rbm_train_loss: 0.0182
# Epoch:273/500 -rbm_train_loss: 0.0187
# Epoch:274/500 -rbm_train_loss: 0.0192
# Epoch:275/500 -rbm_train_loss: 0.0198
# Epoch:276/500 -rbm_train_loss: 0.0204
# Epoch:277/500 -rbm_train_loss: 0.0211
# Epoch:278/500 -rbm_train_loss: 0.0219
# Epoch:279/500 -rbm_train_loss: 0.0226
# Epoch:280/500 -rbm_train_loss: 0.0235
# Epoch:281/500 -rbm_train_loss: 0.0244
# Epoch:282/500 -rbm_train_loss: 0.0253
# Epoch:283/500 -rbm_train_loss: 0.0263
# Epoch:284/500 -rbm_train_loss: 0.0274
# Epoch:285/500 -rbm_train_loss: 0.0284
# Epoch:286/500 -rbm_train_loss: 0.0295
# Epoch:287/500 -rbm_train_loss: 0.0305
# Epoch:288/500 -rbm_train_loss: 0.0314
# Epoch:289/500 -rbm_train_loss: 0.0322
# Epoch:290/500 -rbm_train_loss: 0.0328
# Epoch:291/500 -rbm_train_loss: 0.0331
# Epoch:292/500 -rbm_train_loss: 0.0331
# Epoch:293/500 -rbm_train_loss: 0.0328
# Epoch:294/500 -rbm_train_loss: 0.0321
# Epoch:295/500 -rbm_train_loss: 0.0312
# Epoch:296/500 -rbm_train_loss: 0.0300
# Epoch:297/500 -rbm_train_loss: 0.0287
# Epoch:298/500 -rbm_train_loss: 0.0273
# Epoch:299/500 -rbm_train_loss: 0.0259
# Epoch:300/500 -rbm_train_loss: 0.0246
# Epoch:301/500 -rbm_train_loss: 0.0234
# Epoch:302/500 -rbm_train_loss: 0.0224
# Epoch:303/500 -rbm_train_loss: 0.0214
# Epoch:304/500 -rbm_train_loss: 0.0206
# Epoch:305/500 -rbm_train_loss: 0.0199
# Epoch:306/500 -rbm_train_loss: 0.0192
# Epoch:307/500 -rbm_train_loss: 0.0187
# Epoch:308/500 -rbm_train_loss: 0.0182
# Epoch:309/500 -rbm_train_loss: 0.0177
# Epoch:310/500 -rbm_train_loss: 0.0173
# Epoch:311/500 -rbm_train_loss: 0.0170
# Epoch:312/500 -rbm_train_loss: 0.0166
# Epoch:313/500 -rbm_train_loss: 0.0163
# Epoch:314/500 -rbm_train_loss: 0.0160
# Epoch:315/500 -rbm_train_loss: 0.0158
# Epoch:316/500 -rbm_train_loss: 0.0155
# Epoch:317/500 -rbm_train_loss: 0.0153
# Epoch:318/500 -rbm_train_loss: 0.0150
# Epoch:319/500 -rbm_train_loss: 0.0148
# Epoch:320/500 -rbm_train_loss: 0.0146
# Epoch:321/500 -rbm_train_loss: 0.0144
# Epoch:322/500 -rbm_train_loss: 0.0142
# Epoch:323/500 -rbm_train_loss: 0.0140
# Epoch:324/500 -rbm_train_loss: 0.0138
# Epoch:325/500 -rbm_train_loss: 0.0136
# Epoch:326/500 -rbm_train_loss: 0.0134
# Epoch:327/500 -rbm_train_loss: 0.0133
# Epoch:328/500 -rbm_train_loss: 0.0131
# Epoch:329/500 -rbm_train_loss: 0.0129
# Epoch:330/500 -rbm_train_loss: 0.0128
# Epoch:331/500 -rbm_train_loss: 0.0126
# Epoch:332/500 -rbm_train_loss: 0.0125
# Epoch:333/500 -rbm_train_loss: 0.0123
# Epoch:334/500 -rbm_train_loss: 0.0122
# Epoch:335/500 -rbm_train_loss: 0.0120
# Epoch:336/500 -rbm_train_loss: 0.0119
# Epoch:337/500 -rbm_train_loss: 0.0118
# Epoch:338/500 -rbm_train_loss: 0.0116
# Epoch:339/500 -rbm_train_loss: 0.0115
# Epoch:340/500 -rbm_train_loss: 0.0114
# Epoch:341/500 -rbm_train_loss: 0.0112
# Epoch:342/500 -rbm_train_loss: 0.0111
# Epoch:343/500 -rbm_train_loss: 0.0110
# Epoch:344/500 -rbm_train_loss: 0.0109
# Epoch:345/500 -rbm_train_loss: 0.0108
# Epoch:346/500 -rbm_train_loss: 0.0107
# Epoch:347/500 -rbm_train_loss: 0.0106
# Epoch:348/500 -rbm_train_loss: 0.0105
# Epoch:349/500 -rbm_train_loss: 0.0105
# Epoch:350/500 -rbm_train_loss: 0.0104
# Epoch:351/500 -rbm_train_loss: 0.0103
# Epoch:352/500 -rbm_train_loss: 0.0103
# Epoch:353/500 -rbm_train_loss: 0.0102
# Epoch:354/500 -rbm_train_loss: 0.0102
# Epoch:355/500 -rbm_train_loss: 0.0101
# Epoch:356/500 -rbm_train_loss: 0.0101
# Epoch:357/500 -rbm_train_loss: 0.0101
# Epoch:358/500 -rbm_train_loss: 0.0101
# Epoch:359/500 -rbm_train_loss: 0.0100
# Epoch:360/500 -rbm_train_loss: 0.0100
# Epoch:361/500 -rbm_train_loss: 0.0100
# Epoch:362/500 -rbm_train_loss: 0.0100
# Epoch:363/500 -rbm_train_loss: 0.0100
# Epoch:364/500 -rbm_train_loss: 0.0100
# Epoch:365/500 -rbm_train_loss: 0.0100
# Epoch:366/500 -rbm_train_loss: 0.0100
# Epoch:367/500 -rbm_train_loss: 0.0100
# Epoch:368/500 -rbm_train_loss: 0.0101
# Epoch:369/500 -rbm_train_loss: 0.0101
# Epoch:370/500 -rbm_train_loss: 0.0101
# Epoch:371/500 -rbm_train_loss: 0.0101
# Epoch:372/500 -rbm_train_loss: 0.0101
# Epoch:373/500 -rbm_train_loss: 0.0102
# Epoch:374/500 -rbm_train_loss: 0.0102
# Epoch:375/500 -rbm_train_loss: 0.0102
# Epoch:376/500 -rbm_train_loss: 0.0102
# Epoch:377/500 -rbm_train_loss: 0.0102
# Epoch:378/500 -rbm_train_loss: 0.0103
# Epoch:379/500 -rbm_train_loss: 0.0103
# Epoch:380/500 -rbm_train_loss: 0.0103
# Epoch:381/500 -rbm_train_loss: 0.0104
# Epoch:382/500 -rbm_train_loss: 0.0104
# Epoch:383/500 -rbm_train_loss: 0.0104
# Epoch:384/500 -rbm_train_loss: 0.0104
# Epoch:385/500 -rbm_train_loss: 0.0105
# Epoch:386/500 -rbm_train_loss: 0.0105
# Epoch:387/500 -rbm_train_loss: 0.0105
# Epoch:388/500 -rbm_train_loss: 0.0106
# Epoch:389/500 -rbm_train_loss: 0.0106
# Epoch:390/500 -rbm_train_loss: 0.0106
# Epoch:391/500 -rbm_train_loss: 0.0107
# Epoch:392/500 -rbm_train_loss: 0.0107
# Epoch:393/500 -rbm_train_loss: 0.0108
# Epoch:394/500 -rbm_train_loss: 0.0108
# Epoch:395/500 -rbm_train_loss: 0.0108
# Epoch:396/500 -rbm_train_loss: 0.0109
# Epoch:397/500 -rbm_train_loss: 0.0109
# Epoch:398/500 -rbm_train_loss: 0.0110
# Epoch:399/500 -rbm_train_loss: 0.0110
# Epoch:400/500 -rbm_train_loss: 0.0111
# Epoch:401/500 -rbm_train_loss: 0.0112
# Epoch:402/500 -rbm_train_loss: 0.0112
# Epoch:403/500 -rbm_train_loss: 0.0113
# Epoch:404/500 -rbm_train_loss: 0.0114
# Epoch:405/500 -rbm_train_loss: 0.0114
# Epoch:406/500 -rbm_train_loss: 0.0115
# Epoch:407/500 -rbm_train_loss: 0.0116
# Epoch:408/500 -rbm_train_loss: 0.0117
# Epoch:409/500 -rbm_train_loss: 0.0118
# Epoch:410/500 -rbm_train_loss: 0.0119
# Epoch:411/500 -rbm_train_loss: 0.0120
# Epoch:412/500 -rbm_train_loss: 0.0121
# Epoch:413/500 -rbm_train_loss: 0.0122
# Epoch:414/500 -rbm_train_loss: 0.0123
# Epoch:415/500 -rbm_train_loss: 0.0124
# Epoch:416/500 -rbm_train_loss: 0.0126
# Epoch:417/500 -rbm_train_loss: 0.0127
# Epoch:418/500 -rbm_train_loss: 0.0129
# Epoch:419/500 -rbm_train_loss: 0.0130
# Epoch:420/500 -rbm_train_loss: 0.0132
# Epoch:421/500 -rbm_train_loss: 0.0134
# Epoch:422/500 -rbm_train_loss: 0.0136
# Epoch:423/500 -rbm_train_loss: 0.0138
# Epoch:424/500 -rbm_train_loss: 0.0140
# Epoch:425/500 -rbm_train_loss: 0.0142
# Epoch:426/500 -rbm_train_loss: 0.0144
# Epoch:427/500 -rbm_train_loss: 0.0147
# Epoch:428/500 -rbm_train_loss: 0.0149
# Epoch:429/500 -rbm_train_loss: 0.0152
# Epoch:430/500 -rbm_train_loss: 0.0155
# Epoch:431/500 -rbm_train_loss: 0.0158
# Epoch:432/500 -rbm_train_loss: 0.0161
# Epoch:433/500 -rbm_train_loss: 0.0164
# Epoch:434/500 -rbm_train_loss: 0.0168
# Epoch:435/500 -rbm_train_loss: 0.0171
# Epoch:436/500 -rbm_train_loss: 0.0175
# Epoch:437/500 -rbm_train_loss: 0.0178
# Epoch:438/500 -rbm_train_loss: 0.0181
# Epoch:439/500 -rbm_train_loss: 0.0185
# Epoch:440/500 -rbm_train_loss: 0.0188
# Epoch:441/500 -rbm_train_loss: 0.0191
# Epoch:442/500 -rbm_train_loss: 0.0194
# Epoch:443/500 -rbm_train_loss: 0.0196
# Epoch:444/500 -rbm_train_loss: 0.0198
# Epoch:445/500 -rbm_train_loss: 0.0199
# Epoch:446/500 -rbm_train_loss: 0.0200
# Epoch:447/500 -rbm_train_loss: 0.0200
# Epoch:448/500 -rbm_train_loss: 0.0199
# Epoch:449/500 -rbm_train_loss: 0.0198
# Epoch:450/500 -rbm_train_loss: 0.0196
# Epoch:451/500 -rbm_train_loss: 0.0194
# Epoch:452/500 -rbm_train_loss: 0.0190
# Epoch:453/500 -rbm_train_loss: 0.0187
# Epoch:454/500 -rbm_train_loss: 0.0183
# Epoch:455/500 -rbm_train_loss: 0.0178
# Epoch:456/500 -rbm_train_loss: 0.0173
# Epoch:457/500 -rbm_train_loss: 0.0169
# Epoch:458/500 -rbm_train_loss: 0.0164
# Epoch:459/500 -rbm_train_loss: 0.0159
# Epoch:460/500 -rbm_train_loss: 0.0155
# Epoch:461/500 -rbm_train_loss: 0.0151
# Epoch:462/500 -rbm_train_loss: 0.0146
# Epoch:463/500 -rbm_train_loss: 0.0143
# Epoch:464/500 -rbm_train_loss: 0.0139
# Epoch:465/500 -rbm_train_loss: 0.0135
# Epoch:466/500 -rbm_train_loss: 0.0132
# Epoch:467/500 -rbm_train_loss: 0.0129
# Epoch:468/500 -rbm_train_loss: 0.0126
# Epoch:469/500 -rbm_train_loss: 0.0123
# Epoch:470/500 -rbm_train_loss: 0.0121
# Epoch:471/500 -rbm_train_loss: 0.0118
# Epoch:472/500 -rbm_train_loss: 0.0116
# Epoch:473/500 -rbm_train_loss: 0.0114
# Epoch:474/500 -rbm_train_loss: 0.0112
# Epoch:475/500 -rbm_train_loss: 0.0110
# Epoch:476/500 -rbm_train_loss: 0.0108
# Epoch:477/500 -rbm_train_loss: 0.0107
# Epoch:478/500 -rbm_train_loss: 0.0105
# Epoch:479/500 -rbm_train_loss: 0.0104
# Epoch:480/500 -rbm_train_loss: 0.0103
# Epoch:481/500 -rbm_train_loss: 0.0102
# Epoch:482/500 -rbm_train_loss: 0.0100
# Epoch:483/500 -rbm_train_loss: 0.0100
# Epoch:484/500 -rbm_train_loss: 0.0099
# Epoch:485/500 -rbm_train_loss: 0.0098
# Epoch:486/500 -rbm_train_loss: 0.0097
# Epoch:487/500 -rbm_train_loss: 0.0096
# Epoch:488/500 -rbm_train_loss: 0.0096
# Epoch:489/500 -rbm_train_loss: 0.0095
# Epoch:490/500 -rbm_train_loss: 0.0095
# Epoch:491/500 -rbm_train_loss: 0.0095
# Epoch:492/500 -rbm_train_loss: 0.0095
# Epoch:493/500 -rbm_train_loss: 0.0094
# Epoch:494/500 -rbm_train_loss: 0.0094
# Epoch:495/500 -rbm_train_loss: 0.0094
# Epoch:496/500 -rbm_train_loss: 0.0094
# Epoch:497/500 -rbm_train_loss: 0.0094
# Epoch:498/500 -rbm_train_loss: 0.0094
# Epoch:499/500 -rbm_train_loss: 0.0094
# Epoch:500/500 -rbm_train_loss: 0.0094

# %%
MSE = sum((y_predict - y_test)**2)/494
MSE
# Out:
# tensor(0.0031, dtype=torch.float64)

# %%
RMSE = MSE**0.5
RMSE
# Out:
# tensor(0.0541, dtype=torch.float64)
